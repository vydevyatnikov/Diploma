# %%
import numpy as np
import pandas as pd
import dill as dl
import matplotlib.pyplot as plt
import sys
import pickle
import itertools
import re
import os
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as sm_f

# %%
pd.set_option("max_columns", None)
pd.set_option("max_rows", None)

# %% [markdown]
# # >= 25 specification

# %%
with open("D:/DZ/Course_6/Diploma/Data/two_time_points_25.csv", "rb") as inp:
    two_time_points = pd.read_csv(inp, index_col=0)

# %%
treat_1_roads = two_time_points[["raion", "region", "treatment_1", "treatment_period", "bad_roads"]].copy()
treat_1_roads.dropna(inplace=True)

roads = sm_f.ols(formula="bad_roads ~ treatment_period*treatment_1 + C(region)", data=treat_1_roads).fit(cov_type="HC3")
roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              bad_roads   R-squared:                       0.329
# Model:                            OLS   Adj. R-squared:                  0.299
# Method:                 Least Squares   F-statistic:                     11.53
# Date:                Wed, 10 May 2023   Prob (F-statistic):           1.71e-14
# Time:                        03:00:47   Log-Likelihood:                -933.71
# No. Observations:                 209   AIC:                             1887.
# Df Residuals:                     199   BIC:                             1921.
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            57.7113      4.010     14.391      0.000      49.852      65.571
# C(region)[T.Мурманская область]     -18.9832      6.211     -3.056      0.002     -31.156      -6.810
# C(region)[T.Новгородская область]    -2.6223      4.987     -0.526      0.599     -12.397       7.152
# C(region)[T.Республика Алтай]        22.4039      5.960      3.759      0.000      10.723      34.085
# C(region)[T.Республика Марий Эл]     18.8320      4.755      3.960      0.000       9.512      28.152
# C(region)[T.Тульская область]        -4.1803      5.037     -0.830      0.407     -14.053       5.692
# C(region)[T.Хабаровский край]       -24.0223      6.252     -3.842      0.000     -36.276     -11.769
# treatment_period                     -2.7303      3.365     -0.811      0.417      -9.325       3.865
# treatment_1                          -4.0001      7.468     -0.536      0.592     -18.637      10.637
# treatment_period:treatment_1          4.1894      8.647      0.484      0.628     -12.758      21.137
# ==============================================================================
# Omnibus:                        0.783   Durbin-Watson:                   1.451
# Prob(Omnibus):                  0.676   Jarque-Bera (JB):                0.654
# Skew:                          -0.136   Prob(JB):                        0.721
# Kurtosis:                       3.024   Cond. No.                         7.84
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
treat_1_roads = two_time_points[["raion", "region", "treatment_1", "treatment_period", "bad_roads"]].copy()
treat_1_roads.dropna(inplace=True)

roads = sm_f.ols(formula="bad_roads ~ treatment_period*treatment_1", data=treat_1_roads).fit(cov_type="cluster", cov_kwds={'groups': treat_1_roads['region']})
roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              bad_roads   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                     2.623
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.145
# Time:                        03:00:49   Log-Likelihood:                -974.47
# No. Observations:                 209   AIC:                             1957.
# Df Residuals:                     205   BIC:                             1970.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       58.2794      6.496      8.972      0.000      45.547      71.011
# treatment_period                -4.6883      1.705     -2.750      0.006      -8.029      -1.347
# treatment_1                     -4.9335      6.518     -0.757      0.449     -17.708       7.841
# treatment_period:treatment_1     3.9224      4.202      0.934      0.351      -4.313      12.158
# ==============================================================================
# Omnibus:                       22.478   Durbin-Watson:                   0.976
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                8.805
# Skew:                          -0.249   Prob(JB):                       0.0122
# Kurtosis:                       2.127   Cond. No.                         7.30
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
treat_1_schools = two_time_points[["raion", "region", "treatment_1", "treatment_period", "bad_schools"]].copy()
treat_1_schools.dropna(inplace=True)

schools = sm_f.ols(formula="bad_schools ~ treatment_period*treatment_1", data=treat_1_schools).fit(cov_type="cluster", cov_kwds={'groups': treat_1_schools['region']})
schools.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            bad_schools   R-squared:                       0.054
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                    0.5559
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.661
# Time:                        03:00:50   Log-Likelihood:                -636.49
# No. Observations:                 158   AIC:                             1281.
# Df Residuals:                     154   BIC:                             1293.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        3.4238      1.500      2.283      0.022       0.484       6.364
# treatment_period                 5.5512      5.239      1.060      0.289      -4.717      15.820
# treatment_1                     -0.1591      2.200     -0.072      0.942      -4.472       4.154
# treatment_period:treatment_1     3.9226      6.680      0.587      0.557      -9.169      17.014
# ==============================================================================
# Omnibus:                      136.438   Durbin-Watson:                   2.106
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1528.652
# Skew:                           3.217   Prob(JB):                         0.00
# Kurtosis:                      16.813   Cond. No.                         6.45
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
treat_1_schools = two_time_points[["raion", "region", "treatment_1", "treatment_period", "bad_schools"]].copy()
treat_1_schools.dropna(inplace=True)

schools = sm_f.ols(formula="bad_schools ~ treatment_period*treatment_1 + C(region)", data=treat_1_schools).fit(cov_type="HC3")
schools.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            bad_schools   R-squared:                       0.270
# Model:                            OLS   Adj. R-squared:                  0.220
# Method:                 Least Squares   F-statistic:                     1.199
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.296
# Time:                        03:00:50   Log-Likelihood:                -615.99
# No. Observations:                 158   AIC:                             1254.
# Df Residuals:                     147   BIC:                             1288.
# Df Model:                          10
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            32.2954     19.828      1.629      0.103      -6.567      71.158
# C(region)[T.Мурманская область]     -36.5540     22.868     -1.598      0.110     -81.374       8.266
# C(region)[T.Новгородская область]   -28.6472     20.050     -1.429      0.153     -67.944      10.649
# C(region)[T.Приморский край]        -28.6577     20.124     -1.424      0.154     -68.100      10.785
# C(region)[T.Республика Алтай]       -28.6763     20.516     -1.398      0.162     -68.887      11.535
# C(region)[T.Республика Марий Эл]    -34.4620     20.444     -1.686      0.092     -74.532       5.608
# C(region)[T.Тульская область]       -33.2267     20.065     -1.656      0.098     -72.553       6.100
# C(region)[T.Хабаровский край]       -10.6287     26.372     -0.403      0.687     -62.317      41.060
# treatment_period                      7.1586      3.235      2.213      0.027       0.818      13.499
# treatment_1                           2.1201      2.637      0.804      0.421      -3.047       7.288
# treatment_period:treatment_1          0.5272      6.906      0.076      0.939     -13.009      14.063
# ==============================================================================
# Omnibus:                       80.350   Durbin-Watson:                   2.512
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              332.771
# Skew:                           1.937   Prob(JB):                     5.49e-73
# Kurtosis:                       8.961   Cond. No.                         20.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
treat_1_sewerage = two_time_points[["raion", "region", "treatment_1", "treatment_period", "sewage_grid_fixed"]].copy()
treat_1_sewerage.dropna(inplace=True)

sewerage = sm_f.ols(formula="sewage_grid_fixed ~ treatment_period*treatment_1", data=treat_1_sewerage).fit(cov_type="cluster", cov_kwds={'groups': treat_1_sewerage['region']})
sewerage.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      sewage_grid_fixed   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                     1.593
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.287
# Time:                        03:00:52   Log-Likelihood:                 159.18
# No. Observations:                 103   AIC:                            -310.4
# Df Residuals:                      99   BIC:                            -299.8
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.0172      0.005      3.483      0.000       0.008       0.027
# treatment_period                 0.0086      0.014      0.609      0.542      -0.019       0.036
# treatment_1                      0.0148      0.015      0.968      0.333      -0.015       0.045
# treatment_period:treatment_1    -0.0312      0.016     -1.902      0.057      -0.063       0.001
# ==============================================================================
# Omnibus:                      146.242   Durbin-Watson:                   2.151
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4609.430
# Skew:                           5.193   Prob(JB):                         0.00
# Kurtosis:                      34.084   Cond. No.                         7.48
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
treat_1_sewerage = two_time_points[["raion", "region", "treatment_1", "treatment_period", "sewage_grid_fixed"]].copy()
treat_1_sewerage.dropna(inplace=True)

sewerage = sm_f.ols(formula="sewage_grid_fixed ~ treatment_period*treatment_1 + C(region)", data=treat_1_sewerage).fit(cov_type="HC3")
sewerage.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      sewage_grid_fixed   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                 -0.055
# Method:                 Least Squares   F-statistic:                    0.4187
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.922
# Time:                        03:00:53   Log-Likelihood:                 160.35
# No. Observations:                 103   AIC:                            -300.7
# Df Residuals:                      93   BIC:                            -274.4
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.0097      0.009      1.047      0.295      -0.008       0.028
# C(region)[T.Мурманская область]       0.0216      0.031      0.691      0.489      -0.040       0.083
# C(region)[T.Новгородская область]    -0.0005      0.009     -0.059      0.953      -0.018       0.017
# C(region)[T.Приморский край]          0.0143      0.015      0.950      0.342      -0.015       0.044
# C(region)[T.Республика Алтай]         0.0081      0.066      0.122      0.903      -0.121       0.137
# C(region)[T.Тульская область]         0.0008      0.010      0.082      0.935      -0.018       0.020
# C(region)[T.Хабаровский край]         0.0067      0.009      0.715      0.475      -0.012       0.025
# treatment_period                      0.0087      0.013      0.680      0.497      -0.016       0.034
# treatment_1                           0.0107      0.028      0.386      0.699      -0.044       0.065
# treatment_period:treatment_1         -0.0281      0.029     -0.967      0.333      -0.085       0.029
# ==============================================================================
# Omnibus:                      139.000   Durbin-Watson:                   2.139
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3745.005
# Skew:                           4.840   Prob(JB):                         0.00
# Kurtosis:                      30.909   Cond. No.                         15.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
treat_1_heat = two_time_points[["raion", "region", "treatment_1", "treatment_period", "heat_grid_fixed"]].copy()
treat_1_heat.dropna(inplace=True)

heat = sm_f.ols(formula="heat_grid_fixed ~ treatment_period*treatment_1", data=treat_1_heat).fit(cov_type="HC3") # т.к. в выборке только один регион
heat.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        heat_grid_fixed   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                 -0.037
# Method:                 Least Squares   F-statistic:                    0.3199
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.811
# Time:                        03:00:54   Log-Likelihood:                 126.35
# No. Observations:                  53   AIC:                            -244.7
# Df Residuals:                      49   BIC:                            -236.8
# Df Model:                           3
# Covariance Type:                  HC3
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.0242      0.004      6.614      0.000       0.017       0.031
# treatment_period                 0.0075      0.008      0.907      0.365      -0.009       0.024
# treatment_1                      0.0018      0.009      0.201      0.840      -0.016       0.019
# treatment_period:treatment_1    -0.0040      0.015     -0.263      0.792      -0.034       0.026
# ==============================================================================
# Omnibus:                       38.004   Durbin-Watson:                   1.739
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               94.411
# Skew:                           2.156   Prob(JB):                     3.15e-21
# Kurtosis:                       7.915   Cond. No.                         6.75
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
treat_1_heat = two_time_points[["raion", "region", "treatment_1", "treatment_period", "heat_grid_fixed"]].copy()
treat_1_heat.dropna(inplace=True)

heat = sm_f.ols(formula="heat_grid_fixed ~ treatment_period*treatment_1 + C(region)", data=treat_1_heat).fit(cov_type="HC3") # т.к. в выборке только один регион
heat.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        heat_grid_fixed   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                 -0.037
# Method:                 Least Squares   F-statistic:                    0.3199
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.811
# Time:                        03:00:55   Log-Likelihood:                 126.35
# No. Observations:                  53   AIC:                            -244.7
# Df Residuals:                      49   BIC:                            -236.8
# Df Model:                           3
# Covariance Type:                  HC3
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.0242      0.004      6.614      0.000       0.017       0.031
# treatment_period                 0.0075      0.008      0.907      0.365      -0.009       0.024
# treatment_1                      0.0018      0.009      0.201      0.840      -0.016       0.019
# treatment_period:treatment_1    -0.0040      0.015     -0.263      0.792      -0.034       0.026
# ==============================================================================
# Omnibus:                       38.004   Durbin-Watson:                   1.739
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               94.411
# Skew:                           2.156   Prob(JB):                     3.15e-21
# Kurtosis:                       7.915   Cond. No.                         6.75
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
treat_1_water = two_time_points[["raion", "region", "treatment_1", "treatment_period", "water_grid_fixed"]].copy()
treat_1_water.dropna(inplace=True)

water = sm_f.ols(formula="water_grid_fixed ~ treatment_period*treatment_1", data=treat_1_water).fit(cov_type="cluster", cov_kwds={'groups': treat_1_water['region']})
water.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       water_grid_fixed   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                    0.2921
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.830
# Time:                        03:00:58   Log-Likelihood:                 246.12
# No. Observations:                 167   AIC:                            -484.2
# Df Residuals:                     163   BIC:                            -471.8
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.0284      0.013      2.221      0.026       0.003       0.053
# treatment_period                -0.0100      0.012     -0.838      0.402      -0.033       0.013
# treatment_1                     -0.0125      0.015     -0.848      0.396      -0.042       0.016
# treatment_period:treatment_1     0.0106      0.014      0.765      0.444      -0.017       0.038
# ==============================================================================
# Omnibus:                      323.204   Durbin-Watson:                   1.889
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            93981.561
# Skew:                          10.030   Prob(JB):                         0.00
# Kurtosis:                     117.472   Cond. No.                         7.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
treat_1_water = two_time_points[["raion", "region", "treatment_1", "treatment_period", "water_grid_fixed"]].copy()
treat_1_water.dropna(inplace=True)

water = sm_f.ols(formula="water_grid_fixed ~ treatment_period*treatment_1 + C(region)", data=treat_1_water).fit(cov_type="HC3")
water.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       water_grid_fixed   R-squared:                       0.078
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     3.276
# Date:                Wed, 10 May 2023   Prob (F-statistic):            0.00175
# Time:                        03:00:59   Log-Likelihood:                 252.13
# No. Observations:                 167   AIC:                            -486.3
# Df Residuals:                     158   BIC:                            -458.2
# Df Model:                           8
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.0208      0.007      2.854      0.004       0.007       0.035
# C(region)[T.Мурманская область]       0.0412      0.034      1.212      0.225      -0.025       0.108
# C(region)[T.Новгородская область]    -0.0067      0.005     -1.412      0.158      -0.016       0.003
# C(region)[T.Приморский край]          0.0038      0.005      0.758      0.448      -0.006       0.014
# C(region)[T.Республика Алтай]         0.0059      0.007      0.845      0.398      -0.008       0.020
# C(region)[T.Хабаровский край]         0.0183      0.007      2.605      0.009       0.005       0.032
# treatment_period                     -0.0095      0.010     -0.940      0.347      -0.029       0.010
# treatment_1                          -0.0169      0.016     -1.084      0.278      -0.048       0.014
# treatment_period:treatment_1          0.0104      0.014      0.750      0.454      -0.017       0.038
# ==============================================================================
# Omnibus:                      314.136   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            82135.145
# Skew:                           9.497   Prob(JB):                         0.00
# Kurtosis:                     109.972   Cond. No.                         7.97
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
with open("D:/DZ/Course_6/Diploma/Data/financial_data.csv", "rb") as inp:
    temp_fin = pickle.load(inp)

# %%
with open("D:/DZ/Course_6/Diploma/Data/mun_data_25.csv", "rb") as inp:
    data_for_models = pd.read_csv(inp, index_col=0)

# %%
data_for_models.head()
# Out:
#                 raion           region  treatment_1  treatment_2
# 0     Владивостокский  Приморский край            0            1
# 0     Хасанский район  Приморский край            0            1
# 0         Артемовский  Приморский край            0            1
# 0    Шкотовский район  Приморский край            0            0
# 0  Надеждинский район  Приморский край            0            1

# %%
mapping = {"Приморский край": 2016, "Мурманская область": 2016, "Костромская область": 2015, "Республика Алтай": 2014, "Республика Марий Эл": 2014, "Хабаровский край": 2014, 
           "Тульская область": 2014, "Новгородская область": 2016}

# %%
actual, initial, difference = temp_fin.loc[temp_fin.budget_type == "actual_spending"], temp_fin.loc[temp_fin.budget_type == "initial_budget"], temp_fin.loc[temp_fin.budget_type == "разница"]

# %%
actual = pd.pivot(actual, index = ["region", "raion", "year"], columns="sub_indicator", values="values").reset_index()
initial = pd.pivot(initial, index = ["region", "raion", "year"], columns="sub_indicator", values="values").reset_index()
difference = pd.pivot(difference, index = ["region", "raion", "year"], columns="sub_indicator", values="values").reset_index()

# %%
for i in actual, initial, difference:
    i.rename(columns={"дорожное хозяйство (дорожные фонды)": "roads", "жилищно-коммунальное хозяйство": "housing", "образование": "education"}, inplace=True)

# %%
actual.head()
# Out:
# sub_indicator               region               raion  year       roads  \
# 0              Костромская область  Антроповский район  2013  666.115702
# 1              Костромская область  Антроповский район  2014  603.232937
# 2              Костромская область  Антроповский район  2015  688.908710
# 3              Костромская область  Антроповский район  2016  764.043811
# 4              Костромская область  Антроповский район  2017         NaN
#
# sub_indicator      housing     education
# 0              1610.368144  12882.945154
# 1              1922.796250  12638.114480
# 2                95.255228  21901.154847
# 3               203.425719  10986.123190
# 4                      NaN           NaN

# %%
frames = [actual, initial, difference]

# %%
for i in range(len(frames)):
    temp_fin_data = pd.DataFrame()
    for j in mapping.keys():
        temp_fin_data = temp_fin_data.append(frames[i].loc[(frames[i].region == j) & ((frames[i].year == mapping[j]) | (frames[i].year == mapping[j] + 5))])
    temp_fin_data["treatment_period"] = [1 if i > 2018 else 0 for i in temp_fin_data.year]
    frames[i] = pd.merge(temp_fin_data, data_for_models, on=["region", "raion"], how="inner")

# %%
#frames[0]

# %%
actual, initial, difference = frames

# %%
actual.head()
# Out:
#             region             raion  year        roads      housing  \
# 0  Приморский край  Анучинский район  2016  1915.738966   233.152838
# 1  Приморский край  Анучинский район  2021          NaN          NaN
# 2  Приморский край      Арсеньевский  2016   928.610553  1899.621063
# 3  Приморский край      Арсеньевский  2021   726.384117  3508.931747
# 4  Приморский край       Артемовский  2016    59.130107  1628.357748
#
#       education  treatment_period  treatment_1  treatment_2
# 0  11025.123600                 0            0            1
# 1           NaN                 1            0            1
# 2   9445.185699                 0            0            0
# 3   9828.533690                 1            0            0
# 4   8157.681600                 0            0            1

# %% [markdown]
# ### Models for actual budgets

# %%
actual_roads_data = actual[["raion", "region", "treatment_1", "treatment_period", "roads"]].copy()
actual_roads_data.dropna(inplace=True)
actual_roads = sm_f.ols(formula="roads ~ treatment_period*treatment_1", data=actual_roads_data).fit(cov_type="cluster", cov_kwds={'groups': actual_roads_data['region']})
actual_roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  roads   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     15.13
# Date:                Wed, 10 May 2023   Prob (F-statistic):            0.00192
# Time:                        03:01:24   Log-Likelihood:                -2361.3
# No. Observations:                 271   AIC:                             4731.
# Df Residuals:                     267   BIC:                             4745.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1006.9505    185.276      5.435      0.000     643.816    1370.086
# treatment_period               588.9113    250.333      2.353      0.019      98.267    1079.556
# treatment_1                    320.6475    434.602      0.738      0.461    -531.158    1172.453
# treatment_period:treatment_1  -362.6957    314.284     -1.154      0.248    -978.682     253.290
# ==============================================================================
# Omnibus:                      184.865   Durbin-Watson:                   1.595
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1846.633
# Skew:                           2.689   Prob(JB):                         0.00
# Kurtosis:                      14.603   Cond. No.                         7.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
actual_roads_data = actual[["raion", "region", "treatment_1", "treatment_period", "roads"]].copy()
actual_roads_data.dropna(inplace=True)
actual_roads = sm_f.ols(formula="roads ~ treatment_period*treatment_1 + C(region)", data=actual_roads_data).fit(cov_type="HC3")
actual_roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  roads   R-squared:                       0.135
# Model:                            OLS   Adj. R-squared:                  0.102
# Method:                 Least Squares   F-statistic:                     4.362
# Date:                Wed, 10 May 2023   Prob (F-statistic):           1.16e-05
# Time:                        03:01:26   Log-Likelihood:                -2346.4
# No. Observations:                 271   AIC:                             4715.
# Df Residuals:                     260   BIC:                             4754.
# Df Model:                          10
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          1394.6573    320.948      4.345      0.000     765.610    2023.705
# C(region)[T.Мурманская область]     529.2723    546.458      0.969      0.333    -541.765    1600.310
# C(region)[T.Новгородская область] -1000.3136    364.896     -2.741      0.006   -1715.498    -285.130
# C(region)[T.Приморский край]       -677.8980    345.059     -1.965      0.049   -1354.200      -1.596
# C(region)[T.Республика Алтай]       517.7136    504.225      1.027      0.305    -470.550    1505.977
# C(region)[T.Республика Марий Эл]   -684.7347    384.071     -1.783      0.075   -1437.500      68.030
# C(region)[T.Тульская область]      -171.8380    425.015     -0.404      0.686   -1004.851     661.175
# C(region)[T.Хабаровский край]      -233.5090    436.873     -0.535      0.593   -1089.764     622.746
# treatment_period                    546.8573    203.372      2.689      0.007     148.256     945.459
# treatment_1                         125.9000    372.828      0.338      0.736    -604.830     856.630
# treatment_period:treatment_1       -336.6566    490.747     -0.686      0.493   -1298.502     625.189
# ==============================================================================
# Omnibus:                      185.652   Durbin-Watson:                   1.775
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2050.447
# Skew:                           2.656   Prob(JB):                         0.00
# Kurtosis:                      15.384   Cond. No.                         9.27
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
actual_housing_data = actual[["raion", "region", "treatment_1", "treatment_period", "housing"]].copy()
actual_housing_data.dropna(inplace=True)
actual_housing = sm_f.ols(formula="housing ~ treatment_period*treatment_1", data=actual_housing_data).fit(cov_type="cluster", cov_kwds={'groups': actual_housing_data['region']})
actual_housing.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                housing   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     1.956
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.209
# Time:                        03:01:26   Log-Likelihood:                -2913.0
# No. Observations:                 270   AIC:                             5834.
# Df Residuals:                     266   BIC:                             5848.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     3394.2301   2018.914      1.681      0.093    -562.769    7351.229
# treatment_period              2465.6770   1714.887      1.438      0.150    -895.440    5826.794
# treatment_1                  -1385.9171   1928.657     -0.719      0.472   -5166.016    2394.182
# treatment_period:treatment_1 -2248.1782   1953.145     -1.151      0.250   -6076.272    1579.915
# ==============================================================================
# Omnibus:                      380.409   Durbin-Watson:                   1.129
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            33684.767
# Skew:                           6.802   Prob(JB):                         0.00
# Kurtosis:                      56.001   Cond. No.                         7.24
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
actual_housing_data = actual[["raion", "region", "treatment_1", "treatment_period", "housing"]].copy()
actual_housing_data.dropna(inplace=True)
actual_housing = sm_f.ols(formula="housing ~ treatment_period*treatment_1 + C(region)", data=actual_housing_data).fit(cov_type="HC3")
actual_housing.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                housing   R-squared:                       0.258
# Model:                            OLS   Adj. R-squared:                  0.229
# Method:                 Least Squares   F-statistic:                     5.249
# Date:                Wed, 10 May 2023   Prob (F-statistic):           4.99e-07
# Time:                        03:01:27   Log-Likelihood:                -2874.8
# No. Observations:                 270   AIC:                             5772.
# Df Residuals:                     259   BIC:                             5811.
# Df Model:                          10
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          1111.1840    804.886      1.381      0.167    -466.363    2688.731
# C(region)[T.Мурманская область]    2015.2703    905.247      2.226      0.026     241.019    3789.522
# C(region)[T.Новгородская область] -1384.2604    490.996     -2.819      0.005   -2346.595    -421.925
# C(region)[T.Приморский край]       -341.6306    448.449     -0.762      0.446   -1220.575     537.314
# C(region)[T.Республика Алтай]       822.7961    675.466      1.218      0.223    -501.093    2146.685
# C(region)[T.Республика Марий Эл]   -691.9880    486.415     -1.423      0.155   -1645.343     261.367
# C(region)[T.Тульская область]      1085.9857    700.401      1.551      0.121    -286.774    2458.746
# C(region)[T.Хабаровский край]      1.655e+04   4431.410      3.735      0.000    7864.918    2.52e+04
# treatment_period                   2051.3113   1524.698      1.345      0.178    -937.041    5039.664
# treatment_1                        -237.3240   1079.675     -0.220      0.826   -2353.448    1878.800
# treatment_period:treatment_1      -1983.7994   1982.121     -1.001      0.317   -5868.685    1901.086
# ==============================================================================
# Omnibus:                      359.418   Durbin-Watson:                   1.509
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            30990.668
# Skew:                           6.111   Prob(JB):                         0.00
# Kurtosis:                      54.043   Cond. No.                         9.58
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
actual_education_data = actual[["raion", "region", "treatment_1", "treatment_period", "education"]].copy()
actual_education_data.dropna(inplace=True)
actual_education = sm_f.ols(formula="education ~ treatment_period*treatment_1", data=actual_education_data).fit(cov_type="cluster", cov_kwds={'groups': actual_education_data['region']})
actual_education.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              education   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.2825
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.837
# Time:                        03:01:27   Log-Likelihood:                -2882.4
# No. Observations:                 273   AIC:                             5773.
# Df Residuals:                     269   BIC:                             5787.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1.495e+04   2753.861      5.428      0.000    9550.275    2.03e+04
# treatment_period              1230.2206   1637.083      0.751      0.452   -1978.403    4438.844
# treatment_1                  -1410.9349   2635.112     -0.535      0.592   -6575.659    3753.789
# treatment_period:treatment_1   244.7560    697.577      0.351      0.726   -1122.469    1611.981
# ==============================================================================
# Omnibus:                      167.922   Durbin-Watson:                   0.760
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1204.372
# Skew:                           2.486   Prob(JB):                    2.98e-262
# Kurtosis:                      12.009   Cond. No.                         7.25
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
actual_education_data = actual[["raion", "region", "treatment_1", "treatment_period", "education"]].copy()
actual_education_data.dropna(inplace=True)
actual_education = sm_f.ols(formula="education ~ treatment_period*treatment_1 + C(region)", data=actual_education_data).fit(cov_type="HC3")
actual_education.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              education   R-squared:                       0.459
# Model:                            OLS   Adj. R-squared:                  0.439
# Method:                 Least Squares   F-statistic:                     33.87
# Date:                Wed, 10 May 2023   Prob (F-statistic):           8.58e-42
# Time:                        03:01:28   Log-Likelihood:                -2799.5
# No. Observations:                 273   AIC:                             5621.
# Df Residuals:                     262   BIC:                             5661.
# Df Model:                          10
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          1.493e+04   1058.305     14.112      0.000    1.29e+04     1.7e+04
# C(region)[T.Мурманская область]    8314.3286   1451.977      5.726      0.000    5468.506    1.12e+04
# C(region)[T.Новгородская область] -5973.9930    977.974     -6.109      0.000   -7890.787   -4057.199
# C(region)[T.Приморский край]      -2918.7946   1149.593     -2.539      0.011   -5171.956    -665.633
# C(region)[T.Республика Алтай]      7762.3903   1846.279      4.204      0.000    4143.750    1.14e+04
# C(region)[T.Республика Марий Эл]  -5796.0227   1004.156     -5.772      0.000   -7764.132   -3827.913
# C(region)[T.Тульская область]     -3147.2767   1142.989     -2.754      0.006   -5387.493    -907.060
# C(region)[T.Хабаровский край]      1.146e+04   2694.585      4.254      0.000    6180.135    1.67e+04
# treatment_period                    526.2952    957.033      0.550      0.582   -1349.456    2402.046
# treatment_1                       -1323.4734   1426.255     -0.928      0.353   -4118.881    1471.934
# treatment_period:treatment_1        556.2951   2363.862      0.235      0.814   -4076.789    5189.380
# ==============================================================================
# Omnibus:                      166.068   Durbin-Watson:                   1.349
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1688.210
# Skew:                           2.286   Prob(JB):                         0.00
# Kurtosis:                      14.292   Cond. No.                         9.30
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %% [markdown]
# ### Models for initial budgets

# %%
initial_roads_data = initial[["raion", "region", "treatment_1", "treatment_period", "roads"]].copy()
initial_roads_data.dropna(inplace=True)
initial_roads = sm_f.ols(formula="roads ~ treatment_period*treatment_1", data=initial_roads_data).fit(cov_type="cluster", cov_kwds={'groups': initial_roads_data['region']})
initial_roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  roads   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     48.83
# Date:                Wed, 10 May 2023   Prob (F-statistic):           0.000131
# Time:                        03:01:28   Log-Likelihood:                -1835.9
# No. Observations:                 215   AIC:                             3680.
# Df Residuals:                     211   BIC:                             3693.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      426.5269     69.513      6.136      0.000     290.284     562.769
# treatment_period               684.5470    231.701      2.954      0.003     230.421    1138.673
# treatment_1                    397.8913    310.444      1.282      0.200    -210.567    1006.350
# treatment_period:treatment_1  -453.3234    328.751     -1.379      0.168   -1097.663     191.017
# ==============================================================================
# Omnibus:                      252.084   Durbin-Watson:                   1.858
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10988.613
# Skew:                           4.852   Prob(JB):                         0.00
# Kurtosis:                      36.652   Cond. No.                         7.69
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
initial_roads_data = initial[["raion", "region", "treatment_1", "treatment_period", "roads"]].copy()
initial_roads_data.dropna(inplace=True)
initial_roads = sm_f.ols(formula="roads ~ treatment_period*treatment_1 + C(region)", data=initial_roads_data).fit(cov_type="HC3")
initial_roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  roads   R-squared:                       0.112
# Model:                            OLS   Adj. R-squared:                  0.073
# Method:                 Least Squares   F-statistic:                     3.580
# Date:                Wed, 10 May 2023   Prob (F-statistic):           0.000371
# Time:                        03:01:29   Log-Likelihood:                -1830.2
# No. Observations:                 215   AIC:                             3680.
# Df Residuals:                     205   BIC:                             3714.
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                           569.6962    232.786      2.447      0.014     113.444    1025.948
# C(region)[T.Мурманская область]     483.6891    407.560      1.187      0.235    -315.113    1282.491
# C(region)[T.Новгородская область]  -495.7586    300.584     -1.649      0.099   -1084.893      93.375
# C(region)[T.Приморский край]         -7.6812    325.905     -0.024      0.981    -646.442     631.080
# C(region)[T.Республика Алтай]      -678.0149    375.393     -1.806      0.071   -1413.772      57.742
# C(region)[T.Тульская область]      -138.8262    332.849     -0.417      0.677    -791.197     513.545
# C(region)[T.Хабаровский край]      -268.1688    323.631     -0.829      0.407    -902.475     366.137
# treatment_period                    720.1589    200.765      3.587      0.000     326.667    1113.651
# treatment_1                         271.4842    329.680      0.823      0.410    -374.677     917.646
# treatment_period:treatment_1       -435.6860    421.933     -1.033      0.302   -1262.660     391.288
# ==============================================================================
# Omnibus:                      256.007   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11805.989
# Skew:                           4.956   Prob(JB):                         0.00
# Kurtosis:                      37.923   Cond. No.                         8.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
initial_housing_data = initial[["raion", "region", "treatment_1", "treatment_period", "housing"]].copy()
initial_housing_data.dropna(inplace=True)
initial_housing = sm_f.ols(formula="housing ~ treatment_period*treatment_1", data=initial_housing_data).fit(cov_type="cluster", cov_kwds={'groups': initial_housing_data['region']})
initial_housing.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                housing   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                     1.713
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.263
# Time:                        03:01:30   Log-Likelihood:                -2383.0
# No. Observations:                 224   AIC:                             4774.
# Df Residuals:                     220   BIC:                             4788.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     3076.8736   2002.934      1.536      0.124    -848.805    7002.552
# treatment_period               788.3255   1373.753      0.574      0.566   -1904.180    3480.831
# treatment_1                  -2311.5689   1897.831     -1.218      0.223   -6031.248    1408.111
# treatment_period:treatment_1  -371.6714   1347.919     -0.276      0.783   -3013.545    2270.202
# ==============================================================================
# Omnibus:                      285.250   Durbin-Watson:                   1.067
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12899.193
# Skew:                           5.685   Prob(JB):                         0.00
# Kurtosis:                      38.395   Cond. No.                         7.45
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
initial_housing_data = initial[["raion", "region", "treatment_1", "treatment_period", "housing"]].copy()
initial_housing_data.dropna(inplace=True)
initial_housing = sm_f.ols(formula="housing ~ treatment_period*treatment_1 + C(region)", data=initial_housing_data).fit(cov_type="HC3")
initial_housing.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                housing   R-squared:                       0.214
# Model:                            OLS   Adj. R-squared:                  0.181
# Method:                 Least Squares   F-statistic:                     7.599
# Date:                Wed, 10 May 2023   Prob (F-statistic):           1.18e-09
# Time:                        03:01:30   Log-Likelihood:                -2357.2
# No. Observations:                 224   AIC:                             4734.
# Df Residuals:                     214   BIC:                             4769.
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          1349.2514   1956.562      0.690      0.490   -2485.539    5184.042
# C(region)[T.Мурманская область]     733.3942   1429.851      0.513      0.608   -2069.062    3535.850
# C(region)[T.Новгородская область] -1554.1786   1463.052     -1.062      0.288   -4421.707    1313.350
# C(region)[T.Приморский край]       -660.9325   1435.804     -0.460      0.645   -3475.056    2153.191
# C(region)[T.Республика Алтай]      -619.0590   1323.216     -0.468      0.640   -3212.515    1974.397
# C(region)[T.Тульская область]      -374.7021   1305.073     -0.287      0.774   -2932.598    2183.194
# C(region)[T.Хабаровский край]      1.191e+04   3927.491      3.032      0.002    4209.720    1.96e+04
# treatment_period                    806.0249   1579.019      0.510      0.610   -2288.795    3900.845
# treatment_1                        -938.2314   1197.250     -0.784      0.433   -3284.798    1408.335
# treatment_period:treatment_1       -297.0167   1792.998     -0.166      0.868   -3811.228    3217.194
# ==============================================================================
# Omnibus:                      260.888   Durbin-Watson:                   1.352
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10205.628
# Skew:                           4.917   Prob(JB):                         0.00
# Kurtosis:                      34.571   Cond. No.                         8.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
initial_education_data = initial[["raion", "region", "treatment_1", "treatment_period", "education"]].copy()
initial_education_data.dropna(inplace=True)
initial_education = sm_f.ols(formula="education ~ treatment_period*treatment_1", data=initial_education_data).fit(cov_type="cluster", cov_kwds={'groups': initial_education_data['region']})
initial_education.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              education   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                     1.457
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.317
# Time:                        03:01:31   Log-Likelihood:                -2432.3
# No. Observations:                 231   AIC:                             4873.
# Df Residuals:                     227   BIC:                             4886.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1.285e+04   2909.895      4.417      0.000    7151.063    1.86e+04
# treatment_period              1640.0795   1025.668      1.599      0.110    -370.193    3650.352
# treatment_1                  -1166.3668   2948.022     -0.396      0.692   -6944.384    4611.651
# treatment_period:treatment_1  -312.6310   1090.290     -0.287      0.774   -2449.559    1824.297
# ==============================================================================
# Omnibus:                      124.729   Durbin-Watson:                   0.705
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              691.900
# Skew:                           2.137   Prob(JB):                    5.70e-151
# Kurtosis:                      10.322   Cond. No.                         7.34
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
initial_education_data = initial[["raion", "region", "treatment_1", "treatment_period", "education"]].copy()
initial_education_data.dropna(inplace=True)
initial_education = sm_f.ols(formula="education ~ treatment_period*treatment_1 + C(region)", data=initial_education_data).fit(cov_type="HC3")
initial_education.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              education   R-squared:                       0.443
# Model:                            OLS   Adj. R-squared:                  0.421
# Method:                 Least Squares   F-statistic:                     33.94
# Date:                Wed, 10 May 2023   Prob (F-statistic):           4.40e-37
# Time:                        03:01:31   Log-Likelihood:                -2365.8
# No. Observations:                 231   AIC:                             4752.
# Df Residuals:                     221   BIC:                             4786.
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          8102.4422    746.269     10.857      0.000    6639.782    9565.103
# C(region)[T.Мурманская область]    1.336e+04    951.942     14.033      0.000    1.15e+04    1.52e+04
# C(region)[T.Новгородская область] -1510.5859    718.920     -2.101      0.036   -2919.643    -101.529
# C(region)[T.Приморский край]       3079.4536    835.350      3.686      0.000    1442.199    4716.709
# C(region)[T.Республика Алтай]      9741.6744   1679.688      5.800      0.000    6449.546     1.3e+04
# C(region)[T.Тульская область]      1286.8960    924.777      1.392      0.164    -525.634    3099.426
# C(region)[T.Хабаровский край]      1.422e+04   2531.470      5.616      0.000    9256.343    1.92e+04
# treatment_period                   1424.2998   1059.593      1.344      0.179    -652.465    3501.065
# treatment_1                       -1100.9912   1468.334     -0.750      0.453   -3978.873    1776.890
# treatment_period:treatment_1        253.9473   2183.658      0.116      0.907   -4025.944    4533.839
# ==============================================================================
# Omnibus:                      118.303   Durbin-Watson:                   1.235
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1099.815
# Skew:                           1.775   Prob(JB):                    1.51e-239
# Kurtosis:                      13.083   Cond. No.                         8.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %% [markdown]
# ### Models for difference

# %%
difference_roads_data = difference[["raion", "region", "treatment_1", "treatment_period", "roads"]].copy()
difference_roads_data.dropna(inplace=True)
difference_roads = sm_f.ols(formula="roads ~ treatment_period*treatment_1", data=difference_roads_data).fit(cov_type="cluster", cov_kwds={'groups': difference_roads_data['region']})
difference_roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  roads   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                     1.363
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.341
# Time:                        03:01:32   Log-Likelihood:                -1751.7
# No. Observations:                 206   AIC:                             3511.
# Df Residuals:                     202   BIC:                             3525.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      528.0907    187.279      2.820      0.005     161.031     895.150
# treatment_period               -31.2309    125.654     -0.249      0.804    -277.508     215.046
# treatment_1                   -322.2518    177.942     -1.811      0.070    -671.012      26.509
# treatment_period:treatment_1   351.6293    181.316      1.939      0.052      -3.744     707.003
# ==============================================================================
# Omnibus:                       69.766   Durbin-Watson:                   1.946
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2467.966
# Skew:                          -0.433   Prob(JB):                         0.00
# Kurtosis:                      19.935   Cond. No.                         7.55
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
difference_roads_data = difference[["raion", "region", "treatment_1", "treatment_period", "roads"]].copy()
difference_roads_data.dropna(inplace=True)
difference_roads = sm_f.ols(formula="roads ~ treatment_period*treatment_1 + C(region)", data=difference_roads_data).fit(cov_type="HC3")
difference_roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  roads   R-squared:                       0.084
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     2.863
# Date:                Wed, 10 May 2023   Prob (F-statistic):            0.00341
# Time:                        03:01:33   Log-Likelihood:                -1743.0
# No. Observations:                 206   AIC:                             3506.
# Df Residuals:                     196   BIC:                             3539.
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                           931.8617    266.597      3.495      0.000     409.341    1454.383
# C(region)[T.Мурманская область]    -108.7198    370.815     -0.293      0.769    -835.503     618.064
# C(region)[T.Новгородская область]  -655.6449    247.405     -2.650      0.008   -1140.550    -170.740
# C(region)[T.Приморский край]       -760.8273    290.939     -2.615      0.009   -1331.057    -190.598
# C(region)[T.Республика Алтай]       149.1064    292.192      0.510      0.610    -423.579     721.792
# C(region)[T.Тульская область]        38.1741    385.992      0.099      0.921    -718.357     794.705
# C(region)[T.Хабаровский край]      -143.1661    311.185     -0.460      0.645    -753.077     466.745
# treatment_period                   -144.9731    208.944     -0.694      0.488    -554.495     264.549
# treatment_1                        -412.2985    241.450     -1.708      0.088    -885.532      60.935
# treatment_period:treatment_1        371.7396    347.510      1.070      0.285    -309.367    1052.846
# ==============================================================================
# Omnibus:                       70.536   Durbin-Watson:                   2.113
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2144.609
# Skew:                          -0.529   Prob(JB):                         0.00
# Kurtosis:                      18.771   Cond. No.                         8.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
difference_housing_data = difference[["raion", "region", "treatment_1", "treatment_period", "housing"]].copy()
difference_housing_data.dropna(inplace=True)
difference_housing = sm_f.ols(formula="housing ~ treatment_period*treatment_1", data=difference_housing_data).fit(cov_type="cluster", cov_kwds={'groups': difference_housing_data['region']})
difference_housing.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                housing   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     3.527
# Date:                Wed, 10 May 2023   Prob (F-statistic):             0.0884
# Time:                        03:01:34   Log-Likelihood:                -2144.4
# No. Observations:                 213   AIC:                             4297.
# Df Residuals:                     209   BIC:                             4310.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      678.3971    677.945      1.001      0.317    -650.352    2007.146
# treatment_period              1914.3916    844.461      2.267      0.023     259.279    3569.504
# treatment_1                    631.3809    869.576      0.726      0.468   -1072.956    2335.718
# treatment_period:treatment_1 -2280.2396   1048.711     -2.174      0.030   -4335.676    -224.803
# ==============================================================================
# Omnibus:                       87.700   Durbin-Watson:                   2.066
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11981.653
# Skew:                           0.102   Prob(JB):                         0.00
# Kurtosis:                      39.742   Cond. No.                         7.34
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
difference_housing_data = difference[["raion", "region", "treatment_1", "treatment_period", "housing"]].copy()
difference_housing_data.dropna(inplace=True)
difference_housing = sm_f.ols(formula="housing ~ treatment_period*treatment_1", data=difference_housing_data).fit(cov_type="HC3")
difference_housing.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                housing   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     2.113
# Date:                Wed, 10 May 2023   Prob (F-statistic):             0.0996
# Time:                        03:01:35   Log-Likelihood:                -2144.4
# No. Observations:                 213   AIC:                             4297.
# Df Residuals:                     209   BIC:                             4310.
# Df Model:                           3
# Covariance Type:                  HC3
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      678.3971    692.365      0.980      0.327    -678.614    2035.408
# treatment_period              1914.3916    950.016      2.015      0.044      52.395    3776.389
# treatment_1                    631.3809    926.664      0.681      0.496   -1184.848    2447.609
# treatment_period:treatment_1 -2280.2396   1149.990     -1.983      0.047   -4534.179     -26.301
# ==============================================================================
# Omnibus:                       87.700   Durbin-Watson:                   2.066
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11981.653
# Skew:                           0.102   Prob(JB):                         0.00
# Kurtosis:                      39.742   Cond. No.                         7.34
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
difference_education_data = difference[["raion", "region", "treatment_1", "treatment_period", "education"]].copy()
difference_education_data.dropna(inplace=True)
difference_education = sm_f.ols(formula="education ~ treatment_period*treatment_1", data=difference_education_data).fit(cov_type="cluster", cov_kwds={'groups': difference_education_data['region']})
difference_education.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              education   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.7561
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.558
# Time:                        03:01:36   Log-Likelihood:                -2150.7
# No. Observations:                 219   AIC:                             4309.
# Df Residuals:                     215   BIC:                             4323.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     2969.4054   1445.604      2.054      0.040     136.074    5802.736
# treatment_period              -383.1680   1558.069     -0.246      0.806   -3436.927    2670.591
# treatment_1                   -963.8444    647.525     -1.489      0.137   -2232.970     305.281
# treatment_period:treatment_1   278.6829    950.567      0.293      0.769   -1584.394    2141.760
# ==============================================================================
# Omnibus:                       99.846   Durbin-Watson:                   1.525
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              394.407
# Skew:                           1.865   Prob(JB):                     2.27e-86
# Kurtosis:                       8.414   Cond. No.                         7.35
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
difference_education_data = difference[["raion", "region", "treatment_1", "treatment_period", "education"]].copy()
difference_education_data.dropna(inplace=True)
difference_education = sm_f.ols(formula="education ~ treatment_period*treatment_1 + C(region)", data=difference_education_data).fit(cov_type="HC3")
difference_education.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              education   R-squared:                       0.176
# Model:                            OLS   Adj. R-squared:                  0.141
# Method:                 Least Squares   F-statistic:                     5.524
# Date:                Wed, 10 May 2023   Prob (F-statistic):           8.02e-07
# Time:                        03:01:37   Log-Likelihood:                -2130.2
# No. Observations:                 219   AIC:                             4280.
# Df Residuals:                     209   BIC:                             4314.
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          5994.2350   1013.816      5.913      0.000    4007.192    7981.278
# C(region)[T.Мурманская область]   -4285.6233    986.488     -4.344      0.000   -6219.104   -2352.143
# C(region)[T.Новгородская область] -3761.0789   1066.729     -3.526      0.000   -5851.830   -1670.328
# C(region)[T.Приморский край]      -5267.5414   1003.974     -5.247      0.000   -7235.294   -3299.789
# C(region)[T.Республика Алтай]      -794.3655   1334.020     -0.595      0.552   -3408.997    1820.266
# C(region)[T.Тульская область]     -3684.0401   1111.590     -3.314      0.001   -5862.717   -1505.363
# C(region)[T.Хабаровский край]     -2019.2985   1426.878     -1.415      0.157   -4815.928     777.331
# treatment_period                   -574.2512    644.347     -0.891      0.373   -1837.148     688.646
# treatment_1                        -464.9154    900.214     -0.516      0.606   -2229.303    1299.472
# treatment_period:treatment_1        379.4038   1398.527      0.271      0.786   -2361.660    3120.467
# ==============================================================================
# Omnibus:                       97.735   Durbin-Watson:                   1.809
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              516.998
# Skew:                           1.682   Prob(JB):                    5.44e-113
# Kurtosis:                       9.734   Cond. No.                         8.78
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %% [markdown]
# # Lagged models

# %% [markdown]
# # t+1

# %%
with open("D:/DZ/Course_6/Diploma/Data/full_ind_data.csv", "rb") as inp:
    full_ind_data = pickle.load(inp)

# %%
with open("D:/DZ/Course_6/Diploma/Data/mun_data_25.csv", "rb") as inp:
    mun_data = pd.read_csv(inp, index_col=0)

# %%
mun_data.reset_index(inplace=True, drop=True)

# %%
full_ind_data.shape
# Out:
# (1386, 14)

# %%
full_ind_data.head()
# Out:
#              raion           region  treatment_1  treatment_2  year  \
# 0  Владивостокский  Приморский край            1            1  2013
# 1  Владивостокский  Приморский край            1            1  2014
# 2  Владивостокский  Приморский край            1            1  2015
# 3  Владивостокский  Приморский край            1            1  2016
# 4  Владивостокский  Приморский край            1            1  2017
#
#    bad_roads  bad_schools  unfinished_construction  housing  population  \
# 0        NaN          NaN                  3400.00     4.05    625868.0
# 1        NaN          NaN                  3400.00     3.88    630027.0
# 2        NaN          0.0                 21529.93     5.00    631387.0
# 3        NaN          0.0                  2411.41     5.17    633167.0
# 4        NaN          0.0                      NaN     3.19    633414.0
#
#    lack_transportation  heat_grid_fixed  water_grid_fixed  sewage_grid_fixed
# 0                  NaN         0.050240          0.004470           0.001211
# 1                  NaN         0.020670          0.008552           0.004417
# 2                  NaN         0.019753          0.009448           0.003201
# 3                  NaN         0.011566          0.006601           0.001074
# 4                  NaN         0.013158          0.003128           0.003201

# %%
full_in_data = pd.merge(full_ind_data, mun_data, on=["raion", "region"], how="left")

# %%
full_ind_data = full_in_data.drop(columns=["treatment_1_x", "treatment_2_x"]).rename(columns={"treatment_1_y": "treatment_1", "treatment_2_y": "treatment_2"})

# %%
two_time_points = pd.DataFrame()
for i in mapping.keys():
    two_time_points = two_time_points.append(full_ind_data.loc[(full_ind_data.region == i) & ((full_ind_data.year == mapping[i]) | (full_ind_data.year == mapping[i] + 6))])

two_time_points.reset_index(inplace=True, drop=True)

two_time_points["treatment_period"] = [1 if i > 2018 else 0 for i in two_time_points.year]

# %%
treat_1_roads = two_time_points[["raion", "region", "treatment_1", "treatment_period", "bad_roads"]].copy()
treat_1_roads.dropna(inplace=True)

roads = sm_f.ols(formula="bad_roads ~ treatment_period*treatment_1", data=treat_1_roads).fit(cov_type="cluster", cov_kwds={'groups': treat_1_roads['region']})
roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              bad_roads   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                     1.877
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.234
# Time:                        03:02:06   Log-Likelihood:                -852.08
# No. Observations:                 182   AIC:                             1712.
# Df Residuals:                     178   BIC:                             1725.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       58.2794      6.503      8.962      0.000      45.533      71.025
# treatment_period                -4.1840      3.263     -1.282      0.200     -10.579       2.211
# treatment_1                     -4.9335      6.525     -0.756      0.450     -17.722       7.855
# treatment_period:treatment_1     7.2848      5.495      1.326      0.185      -3.486      18.056
# ==============================================================================
# Omnibus:                       18.970   Durbin-Watson:                   1.076
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                8.558
# Skew:                          -0.314   Prob(JB):                       0.0139
# Kurtosis:                       2.144   Cond. No.                         6.85
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
treat_1_roads = two_time_points[["raion", "region", "treatment_1", "treatment_period", "bad_roads"]].copy()
treat_1_roads.dropna(inplace=True)

roads = sm_f.ols(formula="bad_roads ~ treatment_period*treatment_1 + C(region)", data=treat_1_roads).fit(cov_type="HC3")
roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              bad_roads   R-squared:                       0.350
# Model:                            OLS   Adj. R-squared:                  0.316
# Method:                 Least Squares   F-statistic:                     10.58
# Date:                Wed, 10 May 2023   Prob (F-statistic):           5.58e-13
# Time:                        03:02:08   Log-Likelihood:                -813.47
# No. Observations:                 182   AIC:                             1647.
# Df Residuals:                     172   BIC:                             1679.
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            58.1709      4.142     14.044      0.000      50.053      66.289
# C(region)[T.Мурманская область]     -24.3692      9.712     -2.509      0.012     -43.404      -5.335
# C(region)[T.Новгородская область]    -2.6170      6.441     -0.406      0.685     -15.242      10.008
# C(region)[T.Республика Алтай]        21.1452      6.091      3.472      0.001       9.208      33.083
# C(region)[T.Республика Марий Эл]     19.5707      4.659      4.200      0.000      10.438      28.703
# C(region)[T.Тульская область]        -5.0299      5.055     -0.995      0.320     -14.938       4.878
# C(region)[T.Хабаровский край]       -24.0881      6.255     -3.851      0.000     -36.348     -11.828
# treatment_period                     -4.6701      3.851     -1.213      0.225     -12.218       2.878
# treatment_1                          -3.3719      7.477     -0.451      0.652     -18.027      11.283
# treatment_period:treatment_1          6.1468      8.893      0.691      0.489     -11.284      23.577
# ==============================================================================
# Omnibus:                        1.519   Durbin-Watson:                   1.630
# Prob(Omnibus):                  0.468   Jarque-Bera (JB):                1.148
# Skew:                          -0.161   Prob(JB):                        0.563
# Kurtosis:                       3.219   Cond. No.                         7.65
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
treat_1_schools = two_time_points[["raion", "region", "treatment_1", "treatment_period", "bad_schools"]].copy()
treat_1_schools.dropna(inplace=True)

schools = sm_f.ols(formula="bad_schools ~ treatment_period*treatment_1", data=treat_1_schools).fit(cov_type="cluster", cov_kwds={'groups': treat_1_schools['region']})
schools.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            bad_schools   R-squared:                       0.085
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     19.05
# Date:                Wed, 10 May 2023   Prob (F-statistic):            0.00181
# Time:                        03:02:09   Log-Likelihood:                -433.52
# No. Observations:                 114   AIC:                             875.0
# Df Residuals:                     110   BIC:                             886.0
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        3.4238      1.521      2.251      0.024       0.442       6.406
# treatment_period                11.1944      2.080      5.382      0.000       7.118      15.271
# treatment_1                     -0.1591      2.232     -0.071      0.943      -4.533       4.215
# treatment_period:treatment_1   -11.3091      2.557     -4.422      0.000     -16.321      -6.297
# ==============================================================================
# Omnibus:                       81.954   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              378.947
# Skew:                           2.649   Prob(JB):                     5.16e-83
# Kurtosis:                      10.190   Cond. No.                         9.07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
treat_1_schools = two_time_points[["raion", "region", "treatment_1", "treatment_period", "bad_schools"]].copy()
treat_1_schools.dropna(inplace=True)

schools = sm_f.ols(formula="bad_schools ~ treatment_period*treatment_1 + C(region)", data=treat_1_schools).fit(cov_type="HC3")
schools.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            bad_schools   R-squared:                       0.273
# Model:                            OLS   Adj. R-squared:                  0.210
# Method:                 Least Squares   F-statistic:                     2.201
# Date:                Wed, 10 May 2023   Prob (F-statistic):             0.0276
# Time:                        03:02:09   Log-Likelihood:                -420.46
# No. Observations:                 114   AIC:                             860.9
# Df Residuals:                     104   BIC:                             888.3
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            28.8500     29.911      0.965      0.335     -29.774      87.474
# C(region)[T.Новгородская область]   -26.7246     29.932     -0.893      0.372     -85.390      31.941
# C(region)[T.Приморский край]        -28.8735     29.912     -0.965      0.334     -87.501      29.754
# C(region)[T.Республика Алтай]       -24.5094     30.128     -0.813      0.416     -83.560      34.541
# C(region)[T.Республика Марий Эл]    -26.2247     29.984     -0.875      0.382     -84.992      32.543
# C(region)[T.Тульская область]       -23.8769     29.999     -0.796      0.426     -82.674      34.920
# C(region)[T.Хабаровский край]        -7.1833     34.597     -0.208      0.836     -74.993      60.626
# treatment_period                     10.5894      6.474      1.636      0.102      -2.099      23.278
# treatment_1                           0.1412      1.948      0.072      0.942      -3.676       3.959
# treatment_period:treatment_1        -11.9213      8.123     -1.468      0.142     -27.841       3.999
# ==============================================================================
# Omnibus:                       55.622   Durbin-Watson:                   2.344
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              160.269
# Skew:                           1.852   Prob(JB):                     1.58e-35
# Kurtosis:                       7.474   Cond. No.                         22.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
treat_1_sewerage = two_time_points[["raion", "region", "treatment_1", "treatment_period", "sewage_grid_fixed"]].copy()
treat_1_sewerage.dropna(inplace=True)

sewerage = sm_f.ols(formula="sewage_grid_fixed ~ treatment_period*treatment_1", data=treat_1_sewerage).fit(cov_type="cluster", cov_kwds={'groups': treat_1_sewerage['region']})
sewerage.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      sewage_grid_fixed   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                 -0.027
# Method:                 Least Squares   F-statistic:                     21.59
# Date:                Wed, 10 May 2023   Prob (F-statistic):            0.00273
# Time:                        03:02:10   Log-Likelihood:                 112.19
# No. Observations:                  63   AIC:                            -216.4
# Df Residuals:                      59   BIC:                            -207.8
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.0172      0.005      3.401      0.001       0.007       0.027
# treatment_period                -0.0043      0.006     -0.670      0.503      -0.017       0.008
# treatment_1                      0.0148      0.016      0.945      0.345      -0.016       0.045
# treatment_period:treatment_1    -0.0218      0.016     -1.372      0.170      -0.053       0.009
# ==============================================================================
# Omnibus:                       87.452   Durbin-Watson:                   2.214
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1100.645
# Skew:                           4.169   Prob(JB):                    9.96e-240
# Kurtosis:                      21.702   Cond. No.                         6.68
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
treat_1_sewerage = two_time_points[["raion", "region", "treatment_1", "treatment_period", "sewage_grid_fixed"]].copy()
treat_1_sewerage.dropna(inplace=True)

sewerage = sm_f.ols(formula="sewage_grid_fixed ~ treatment_period*treatment_1 + C(region)", data=treat_1_sewerage).fit(cov_type="HC3")
sewerage.summary()
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\regression\linear_model.py:1908: RuntimeWarning: divide by zero encountered in true_divide
#   self.het_scale = (self.wresid / (1 - h))**2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-c1a007c98a78> in <module>
#       3
#       4 sewerage = sm_f.ols(formula="sewage_grid_fixed ~ treatment_period*treatment_1 + C(region)", data=treat_1_sewerage).fit(cov_type="HC3")
# ----> 5 sewerage.summary()
#
# D:\Anaconda\lib\site-packages\statsmodels\regression\linear_model.py in summary(self, yname, xname, title, alpha)
#    2641                      ('Adj. R-squared' + rsquared_type + ':',
#    2642                       ["%#8.3f" % self.rsquared_adj]),
# -> 2643                      ('F-statistic:', ["%#8.4g" % self.fvalue]),
#    2644                      ('Prob (F-statistic):', ["%#6.3g" % self.f_pvalue]),
#    2645                      ('Log-Likelihood:', None),
#
# pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# D:\Anaconda\lib\site-packages\statsmodels\regression\linear_model.py in fvalue(self)
#    1796                 if mat.size == 0:  # see  #3642
#    1797                     return np.nan
# -> 1798             ft = self.f_test(mat)
#    1799             # using backdoor to set another attribute that we already have
#    1800             self._cache['f_pvalue'] = float(ft.pvalue)
#
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py in f_test(self, r_matrix, cov_p, scale, invcov)
#    1723                           DeprecationWarning)
#    1724
# -> 1725         res = self.wald_test(r_matrix, cov_p=cov_p, invcov=invcov, use_f=True)
#    1726         return res
#    1727
#
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py in wald_test(self, r_matrix, cov_p, scale, invcov, use_f, df_constraints)
#    1824             cov_p = self.cov_params(r_matrix=r_matrix, cov_p=cov_p)
#    1825             if np.isnan(cov_p).max():
# -> 1826                 raise ValueError("r_matrix performs f_test for using "
#    1827                                  "dimensions that are asymptotically "
#    1828                                  "non-normal")
#
# ValueError: r_matrix performs f_test for using dimensions that are asymptotically non-normal

# %%
treat_1_heat = two_time_points[["raion", "region", "treatment_1", "treatment_period", "heat_grid_fixed"]].copy()
treat_1_heat.dropna(inplace=True)

heat = sm_f.ols(formula="heat_grid_fixed ~ treatment_period*treatment_1", data=treat_1_heat).fit(cov_type="HC3") # т.к. в выборке только один регион
heat.summary()
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\regression\linear_model.py:1860: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.sqrt(eigvals[0]/eigvals[-1])
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py:1832: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        heat_grid_fixed   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.034
# Method:                 Least Squares   F-statistic:                   0.04059
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.842
# Time:                        03:02:28   Log-Likelihood:                 79.512
# No. Observations:                  30   AIC:                            -155.0
# Df Residuals:                      28   BIC:                            -152.2
# Df Model:                           1
# Covariance Type:                  HC3
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.0242      0.004      6.614      0.000       0.017       0.031
# treatment_period                      0          0        nan        nan           0           0
# treatment_1                      0.0018      0.009      0.201      0.840      -0.016       0.019
# treatment_period:treatment_1          0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                       25.319   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.855
# Skew:                           1.951   Prob(JB):                     3.00e-10
# Kurtosis:                       7.456   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
treat_1_water = two_time_points[["raion", "region", "treatment_1", "treatment_period", "water_grid_fixed"]].copy()
treat_1_water.dropna(inplace=True)

water = sm_f.ols(formula="water_grid_fixed ~ treatment_period*treatment_1", data=treat_1_water).fit(cov_type="cluster", cov_kwds={'groups': treat_1_water['region']})
water.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       water_grid_fixed   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.016
# Method:                 Least Squares   F-statistic:                     16.14
# Date:                Wed, 10 May 2023   Prob (F-statistic):            0.00527
# Time:                        03:02:32   Log-Likelihood:                 148.80
# No. Observations:                 123   AIC:                            -289.6
# Df Residuals:                     119   BIC:                            -278.3
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.0284      0.013      2.213      0.027       0.003       0.054
# treatment_period                 0.0081      0.014      0.597      0.551      -0.019       0.035
# treatment_1                     -0.0125      0.015     -0.845      0.398      -0.042       0.017
# treatment_period:treatment_1    -0.0133      0.016     -0.842      0.400      -0.044       0.018
# ==============================================================================
# Omnibus:                      204.189   Durbin-Watson:                   2.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16773.398
# Skew:                           6.922   Prob(JB):                         0.00
# Kurtosis:                      58.509   Cond. No.                         6.83
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
treat_1_water = two_time_points[["raion", "region", "treatment_1", "treatment_period", "water_grid_fixed"]].copy()
treat_1_water.dropna(inplace=True)

water = sm_f.ols(formula="water_grid_fixed ~ treatment_period*treatment_1 + C(region)", data=treat_1_water).fit(cov_type="HC3")
water.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       water_grid_fixed   R-squared:                       0.098
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     3.732
# Date:                Wed, 10 May 2023   Prob (F-statistic):           0.000653
# Time:                        03:02:33   Log-Likelihood:                 154.58
# No. Observations:                 123   AIC:                            -291.2
# Df Residuals:                     114   BIC:                            -265.9
# Df Model:                           8
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.0200      0.008      2.409      0.016       0.004       0.036
# C(region)[T.Мурманская область]       0.0722      0.066      1.100      0.271      -0.056       0.201
# C(region)[T.Новгородская область]    -0.0139      0.008     -1.744      0.081      -0.030       0.002
# C(region)[T.Приморский край]          0.0023      0.009      0.255      0.799      -0.015       0.020
# C(region)[T.Республика Алтай]        -0.0076      0.018     -0.425      0.671      -0.042       0.027
# C(region)[T.Хабаровский край]         0.0149      0.015      0.991      0.322      -0.015       0.044
# treatment_period                      0.0111      0.018      0.636      0.525      -0.023       0.045
# treatment_1                          -0.0210      0.021     -1.007      0.314      -0.062       0.020
# treatment_period:treatment_1         -0.0007      0.027     -0.028      0.978      -0.053       0.052
# ==============================================================================
# Omnibus:                      187.285   Durbin-Watson:                   2.105
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11285.422
# Skew:                           6.035   Prob(JB):                         0.00
# Kurtosis:                      48.347   Cond. No.                         7.40
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %% [markdown]
# # Fin t+1

# %%
with open("D:/DZ/Course_6/Diploma/Data/financial_data.csv", "rb") as inp:
    temp_fin = pickle.load(inp)

# %%
with open("D:/DZ/Course_6/Diploma/Data/mun_data_25.csv", "rb") as inp:
    data_for_models = pd.read_csv(inp, index_col=0)

# %%
mapping = {"Приморский край": 2016, "Мурманская область": 2016, "Костромская область": 2015, "Республика Алтай": 2014, "Республика Марий Эл": 2014, "Хабаровский край": 2014, 
           "Тульская область": 2014, "Новгородская область": 2016}

# %%
actual, initial, difference = temp_fin.loc[temp_fin.budget_type == "actual_spending"], temp_fin.loc[temp_fin.budget_type == "initial_budget"], temp_fin.loc[temp_fin.budget_type == "разница"]

# %%
actual = pd.pivot(actual, index = ["region", "raion", "year"], columns="sub_indicator", values="values").reset_index()
initial = pd.pivot(initial, index = ["region", "raion", "year"], columns="sub_indicator", values="values").reset_index()
difference = pd.pivot(difference, index = ["region", "raion", "year"], columns="sub_indicator", values="values").reset_index()

# %%
for i in actual, initial, difference:
    i.rename(columns={"дорожное хозяйство (дорожные фонды)": "roads", "жилищно-коммунальное хозяйство": "housing", "образование": "education"}, inplace=True)

# %%
actual.head()
# Out:
# sub_indicator               region               raion  year       roads  \
# 0              Костромская область  Антроповский район  2013  666.115702
# 1              Костромская область  Антроповский район  2014  603.232937
# 2              Костромская область  Антроповский район  2015  688.908710
# 3              Костромская область  Антроповский район  2016  764.043811
# 4              Костромская область  Антроповский район  2017         NaN
#
# sub_indicator      housing     education
# 0              1610.368144  12882.945154
# 1              1922.796250  12638.114480
# 2                95.255228  21901.154847
# 3               203.425719  10986.123190
# 4                      NaN           NaN

# %%
frames = [actual, initial, difference]

# %%
for i in range(len(frames)):
    temp_fin_data = pd.DataFrame()
    for j in mapping.keys():
        temp_fin_data = temp_fin_data.append(frames[i].loc[(frames[i].region == j) & ((frames[i].year == mapping[j]) | (frames[i].year == mapping[j] + 6))])
    temp_fin_data["treatment_period"] = [1 if i > 2018 else 0 for i in temp_fin_data.year]
    frames[i] = pd.merge(temp_fin_data, data_for_models, on=["region", "raion"], how="inner")

# %%
#frames[0]

# %%
actual, initial, difference = frames

# %% [markdown]
# ### Models for actual budgets

# %%
actual_roads_data = actual[["raion", "region", "treatment_1", "treatment_period", "roads"]].copy()
actual_roads_data.dropna(inplace=True)
actual_roads = sm_f.ols(formula="roads ~ treatment_period*treatment_1", data=actual_roads_data).fit(cov_type="cluster", cov_kwds={'groups': actual_roads_data['region']})
actual_roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  roads   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     6.354
# Date:                Wed, 10 May 2023   Prob (F-statistic):             0.0208
# Time:                        03:02:42   Log-Likelihood:                -1760.4
# No. Observations:                 203   AIC:                             3529.
# Df Residuals:                     199   BIC:                             3542.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1006.9505    185.628      5.425      0.000     643.127    1370.774
# treatment_period               657.9602    298.883      2.201      0.028      72.161    1243.759
# treatment_1                    320.6475    435.427      0.736      0.461    -532.773    1174.068
# treatment_period:treatment_1  -476.4981    310.768     -1.533      0.125   -1085.591     132.595
# ==============================================================================
# Omnibus:                       95.209   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              308.570
# Skew:                           2.015   Prob(JB):                     9.88e-68
# Kurtosis:                       7.499   Cond. No.                         7.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
actual_roads_data = actual[["raion", "region", "treatment_1", "treatment_period", "roads"]].copy()
actual_roads_data.dropna(inplace=True)
actual_roads = sm_f.ols(formula="roads ~ treatment_period*treatment_1 + C(region)", data=actual_roads_data).fit(cov_type="HC3")
actual_roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  roads   R-squared:                       0.161
# Model:                            OLS   Adj. R-squared:                  0.118
# Method:                 Least Squares   F-statistic:                     4.166
# Date:                Wed, 10 May 2023   Prob (F-statistic):           3.14e-05
# Time:                        03:02:42   Log-Likelihood:                -1746.6
# No. Observations:                 203   AIC:                             3515.
# Df Residuals:                     192   BIC:                             3552.
# Df Model:                          10
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          1237.1216    275.368      4.493      0.000     697.410    1776.833
# C(region)[T.Мурманская область]    1167.9430    922.676      1.266      0.206    -640.468    2976.354
# C(region)[T.Новгородская область]  -817.8101    294.790     -2.774      0.006   -1395.587    -240.033
# C(region)[T.Приморский край]       -676.1180    289.688     -2.334      0.020   -1243.896    -108.340
# C(region)[T.Республика Алтай]       606.9523    469.010      1.294      0.196    -312.291    1526.195
# C(region)[T.Республика Марий Эл]   -417.7482    308.718     -1.353      0.176   -1022.824     187.328
# C(region)[T.Тульская область]      -527.1398    350.565     -1.504      0.133   -1214.234     159.954
# C(region)[T.Хабаровский край]       306.3165    398.089      0.769      0.442    -473.924    1086.557
# treatment_period                    348.8834    296.975      1.175      0.240    -233.177     930.943
# treatment_1                         268.7891    372.851      0.721      0.471    -461.985     999.563
# treatment_period:treatment_1       -529.4796    717.407     -0.738      0.460   -1935.571     876.611
# ==============================================================================
# Omnibus:                       80.981   Durbin-Watson:                   2.102
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              242.641
# Skew:                           1.703   Prob(JB):                     2.05e-53
# Kurtosis:                       7.134   Cond. No.                         8.55
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
actual_housing_data = actual[["raion", "region", "treatment_1", "treatment_period", "housing"]].copy()
actual_housing_data.dropna(inplace=True)
actual_housing = sm_f.ols(formula="housing ~ treatment_period*treatment_1", data=actual_housing_data).fit(cov_type="cluster", cov_kwds={'groups': actual_housing_data['region']})
actual_housing.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                housing   R-squared:                       0.045
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     1.161
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.390
# Time:                        03:02:43   Log-Likelihood:                -2161.1
# No. Observations:                 202   AIC:                             4330.
# Df Residuals:                     198   BIC:                             4343.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     3394.2301   2022.777      1.678      0.093    -570.340    7358.800
# treatment_period              4847.2332   2722.600      1.780      0.075    -488.965    1.02e+04
# treatment_1                  -1385.9171   1932.347     -0.717      0.473   -5173.248    2401.414
# treatment_period:treatment_1 -5256.9201   2965.767     -1.773      0.076   -1.11e+04     555.877
# ==============================================================================
# Omnibus:                      270.774   Durbin-Watson:                   1.079
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16298.883
# Skew:                           5.865   Prob(JB):                         0.00
# Kurtosis:                      45.414   Cond. No.                         7.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
actual_housing_data = actual[["raion", "region", "treatment_1", "treatment_period", "housing"]].copy()
actual_housing_data.dropna(inplace=True)
actual_housing = sm_f.ols(formula="housing ~ treatment_period*treatment_1 + C(region)", data=actual_housing_data).fit(cov_type="HC3")
actual_housing.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                housing   R-squared:                       0.260
# Model:                            OLS   Adj. R-squared:                  0.222
# Method:                 Least Squares   F-statistic:                     5.929
# Date:                Wed, 10 May 2023   Prob (F-statistic):           8.51e-08
# Time:                        03:02:43   Log-Likelihood:                -2135.2
# No. Observations:                 202   AIC:                             4292.
# Df Residuals:                     191   BIC:                             4329.
# Df Model:                          10
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          1902.4312    989.901      1.922      0.055     -37.739    3842.602
# C(region)[T.Мурманская область]    1453.5165   1191.002      1.220      0.222    -880.805    3787.838
# C(region)[T.Новгородская область] -1331.6849   1031.784     -1.291      0.197   -3353.945     690.575
# C(region)[T.Приморский край]      -1065.5587    945.945     -1.126      0.260   -2919.577     788.459
# C(region)[T.Республика Алтай]       216.8094    940.596      0.231      0.818   -1626.725    2060.344
# C(region)[T.Республика Марий Эл]  -1048.8472    774.435     -1.354      0.176   -2566.713     469.018
# C(region)[T.Тульская область]      1650.2768   1253.276      1.317      0.188    -806.099    4106.652
# C(region)[T.Хабаровский край]      1.282e+04   3455.286      3.709      0.000    6044.238    1.96e+04
# treatment_period                   2341.5087   2380.311      0.984      0.325   -2323.815    7006.833
# treatment_1                        -728.2300    869.050     -0.838      0.402   -2431.538     975.078
# treatment_period:treatment_1      -3950.6247   3465.352     -1.140      0.254   -1.07e+04    2841.340
# ==============================================================================
# Omnibus:                      266.053   Durbin-Watson:                   1.367
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18157.480
# Skew:                           5.601   Prob(JB):                         0.00
# Kurtosis:                      48.076   Cond. No.                         8.77
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
actual_education_data = actual[["raion", "region", "treatment_1", "treatment_period", "education"]].copy()
actual_education_data.dropna(inplace=True)
actual_education = sm_f.ols(formula="education ~ treatment_period*treatment_1", data=actual_education_data).fit(cov_type="cluster", cov_kwds={'groups': actual_education_data['region']})
actual_education.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              education   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                    0.7730
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.545
# Time:                        03:02:44   Log-Likelihood:                -2162.3
# No. Observations:                 204   AIC:                             4333.
# Df Residuals:                     200   BIC:                             4346.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1.495e+04   2759.095      5.418      0.000    9540.016    2.04e+04
# treatment_period              4122.3179   3478.924      1.185      0.236   -2696.248    1.09e+04
# treatment_1                  -1410.9349   2640.120     -0.534      0.593   -6585.476    3763.606
# treatment_period:treatment_1 -4399.3790   3244.837     -1.356      0.175   -1.08e+04    1960.384
# ==============================================================================
# Omnibus:                      133.821   Durbin-Watson:                   0.782
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              929.145
# Skew:                           2.559   Prob(JB):                    1.73e-202
# Kurtosis:                      12.117   Cond. No.                         7.68
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
actual_education_data = actual[["raion", "region", "treatment_1", "treatment_period", "education"]].copy()
actual_education_data.dropna(inplace=True)
actual_education = sm_f.ols(formula="education ~ treatment_period*treatment_1", data=actual_education_data).fit(cov_type="HC3")
actual_education.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              education   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     2.872
# Date:                Wed, 10 May 2023   Prob (F-statistic):             0.0375
# Time:                        03:03:09   Log-Likelihood:                -2162.3
# No. Observations:                 204   AIC:                             4333.
# Df Residuals:                     200   BIC:                             4346.
# Df Model:                           3
# Covariance Type:                  HC3
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1.495e+04    863.652     17.308      0.000    1.33e+04    1.66e+04
# treatment_period              4122.3179   1877.111      2.196      0.028     443.248    7801.388
# treatment_1                  -1410.9349   1286.923     -1.096      0.273   -3933.258    1111.388
# treatment_period:treatment_1 -4399.3790   3600.473     -1.222      0.222   -1.15e+04    2657.418
# ==============================================================================
# Omnibus:                      133.821   Durbin-Watson:                   0.782
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              929.145
# Skew:                           2.559   Prob(JB):                    1.73e-202
# Kurtosis:                      12.117   Cond. No.                         7.68
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %% [markdown]
# ### Models for initial budgets

# %%
initial_roads_data = initial[["raion", "region", "treatment_1", "treatment_period", "roads"]].copy()
initial_roads_data.dropna(inplace=True)
initial_roads = sm_f.ols(formula="roads ~ treatment_period*treatment_1", data=initial_roads_data).fit(cov_type="cluster", cov_kwds={'groups': initial_roads_data['region']})
initial_roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  roads   R-squared:                       0.164
# Model:                            OLS   Adj. R-squared:                  0.149
# Method:                 Least Squares   F-statistic:                     36.60
# Date:                Wed, 10 May 2023   Prob (F-statistic):           0.000298
# Time:                        03:03:13   Log-Likelihood:                -1359.5
# No. Observations:                 166   AIC:                             2727.
# Df Residuals:                     162   BIC:                             2739.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      426.5269     69.660      6.123      0.000     289.996     563.058
# treatment_period               685.8212    170.309      4.027      0.000     352.021    1019.622
# treatment_1                    397.8913    311.101      1.279      0.201    -211.856    1007.638
# treatment_period:treatment_1    71.9648    265.318      0.271      0.786    -448.049     591.978
# ==============================================================================
# Omnibus:                       98.927   Durbin-Watson:                   1.733
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              536.081
# Skew:                           2.247   Prob(JB):                    3.90e-117
# Kurtosis:                      10.571   Cond. No.                         6.83
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
initial_roads_data = initial[["raion", "region", "treatment_1", "treatment_period", "roads"]].copy()
initial_roads_data.dropna(inplace=True)
initial_roads = sm_f.ols(formula="roads ~ treatment_period*treatment_1 + C(region)", data=initial_roads_data).fit(cov_type="HC3")
initial_roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  roads   R-squared:                       0.236
# Model:                            OLS   Adj. R-squared:                  0.191
# Method:                 Least Squares   F-statistic:                     5.123
# Date:                Wed, 10 May 2023   Prob (F-statistic):           4.45e-06
# Time:                        03:03:15   Log-Likelihood:                -1352.1
# No. Observations:                 166   AIC:                             2724.
# Df Residuals:                     156   BIC:                             2755.
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                           343.9114    129.769      2.650      0.008      89.568     598.255
# C(region)[T.Мурманская область]     871.1858    551.703      1.579      0.114    -210.132    1952.504
# C(region)[T.Новгородская область]  -125.1601    139.817     -0.895      0.371    -399.196     148.876
# C(region)[T.Приморский край]         92.9883    156.465      0.594      0.552    -213.678     399.654
# C(region)[T.Республика Алтай]      -659.8114    232.479     -2.838      0.005   -1115.463    -204.160
# C(region)[T.Тульская область]       -30.0624    294.628     -0.102      0.919    -607.523     547.398
# C(region)[T.Хабаровский край]       125.7163    229.342      0.548      0.584    -323.786     575.218
# treatment_period                    840.3968    203.870      4.122      0.000     440.819    1239.974
# treatment_1                         339.3279    315.922      1.074      0.283    -279.869     958.525
# treatment_period:treatment_1        164.2820    518.831      0.317      0.752    -852.609    1181.173
# ==============================================================================
# Omnibus:                       87.620   Durbin-Watson:                   1.894
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              428.508
# Skew:                           1.970   Prob(JB):                     8.93e-94
# Kurtosis:                       9.814   Cond. No.                         7.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
initial_housing_data = initial[["raion", "region", "treatment_1", "treatment_period", "housing"]].copy()
initial_housing_data.dropna(inplace=True)
initial_housing = sm_f.ols(formula="housing ~ treatment_period*treatment_1", data=initial_housing_data).fit(cov_type="cluster", cov_kwds={'groups': initial_housing_data['region']})
initial_housing.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                housing   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                    0.9514
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.473
# Time:                        03:03:18   Log-Likelihood:                -1871.2
# No. Observations:                 174   AIC:                             3750.
# Df Residuals:                     170   BIC:                             3763.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     3076.8736   2006.892      1.533      0.125    -856.563    7010.311
# treatment_period              3638.3665   3438.202      1.058      0.290   -3100.385    1.04e+04
# treatment_1                  -2311.5689   1901.581     -1.216      0.224   -6038.600    1415.462
# treatment_period:treatment_1 -3461.1915   3360.989     -1.030      0.303      -1e+04    3126.226
# ==============================================================================
# Omnibus:                      207.388   Durbin-Watson:                   1.180
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5824.415
# Skew:                           4.906   Prob(JB):                         0.00
# Kurtosis:                      29.591   Cond. No.                         6.69
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
initial_housing_data = initial[["raion", "region", "treatment_1", "treatment_period", "housing"]].copy()
initial_housing_data.dropna(inplace=True)
initial_housing = sm_f.ols(formula="housing ~ treatment_period*treatment_1 + C(region)", data=initial_housing_data).fit(cov_type="HC3")
initial_housing.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                housing   R-squared:                       0.201
# Model:                            OLS   Adj. R-squared:                  0.157
# Method:                 Least Squares   F-statistic:                     6.337
# Date:                Wed, 10 May 2023   Prob (F-statistic):           1.10e-07
# Time:                        03:03:19   Log-Likelihood:                -1854.6
# No. Observations:                 174   AIC:                             3729.
# Df Residuals:                     164   BIC:                             3761.
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          1409.6631   2756.901      0.511      0.609   -3993.763    6813.090
# C(region)[T.Мурманская область]     523.9893   2605.323      0.201      0.841   -4582.351    5630.329
# C(region)[T.Новгородская область] -1300.7685   2713.003     -0.479      0.632   -6618.157    4016.620
# C(region)[T.Приморский край]       -723.4824   2587.600     -0.280      0.780   -5795.086    4348.121
# C(region)[T.Республика Алтай]      -697.6344   1429.953     -0.488      0.626   -3500.291    2105.022
# C(region)[T.Тульская область]       -15.1793   1465.354     -0.010      0.992   -2887.221    2856.862
# C(region)[T.Хабаровский край]      1.138e+04   3955.816      2.876      0.004    3621.879    1.91e+04
# treatment_period                   1632.1046   3078.528      0.530      0.596   -4401.699    7665.908
# treatment_1                       -1040.3233   1293.597     -0.804      0.421   -3575.726    1495.080
# treatment_period:treatment_1      -1819.6411   2575.875     -0.706      0.480   -6868.264    3228.982
# ==============================================================================
# Omnibus:                      193.718   Durbin-Watson:                   1.415
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4987.257
# Skew:                           4.409   Prob(JB):                         0.00
# Kurtosis:                      27.701   Cond. No.                         8.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
initial_education_data = initial[["raion", "region", "treatment_1", "treatment_period", "education"]].copy()
initial_education_data.dropna(inplace=True)
initial_education = sm_f.ols(formula="education ~ treatment_period*treatment_1", data=initial_education_data).fit(cov_type="cluster", cov_kwds={'groups': initial_education_data['region']})
initial_education.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              education   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                    0.6843
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.593
# Time:                        03:03:22   Log-Likelihood:                -1911.5
# No. Observations:                 181   AIC:                             3831.
# Df Residuals:                     177   BIC:                             3844.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1.285e+04   2915.251      4.409      0.000    7140.566    1.86e+04
# treatment_period              2700.1449   2859.653      0.944      0.345   -2904.673    8304.962
# treatment_1                  -1166.3668   2953.449     -0.395      0.693   -6955.020    4622.286
# treatment_period:treatment_1 -3734.5300   2918.499     -1.280      0.201   -9454.682    1985.622
# ==============================================================================
# Omnibus:                      115.052   Durbin-Watson:                   0.799
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              730.346
# Skew:                           2.420   Prob(JB):                    2.55e-159
# Kurtosis:                      11.568   Cond. No.                         6.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
initial_education_data = initial[["raion", "region", "treatment_1", "treatment_period", "education"]].copy()
initial_education_data.dropna(inplace=True)
initial_education = sm_f.ols(formula="education ~ treatment_period*treatment_1 + C(region)", data=initial_education_data).fit(cov_type="HC3")
initial_education.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              education   R-squared:                       0.398
# Model:                            OLS   Adj. R-squared:                  0.367
# Method:                 Least Squares   F-statistic:                     23.34
# Date:                Wed, 10 May 2023   Prob (F-statistic):           1.24e-25
# Time:                        03:03:25   Log-Likelihood:                -1867.9
# No. Observations:                 181   AIC:                             3756.
# Df Residuals:                     171   BIC:                             3788.
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          8330.0806   1136.373      7.330      0.000    6102.830    1.06e+04
# C(region)[T.Мурманская область]    1.163e+04   1375.841      8.453      0.000    8933.379    1.43e+04
# C(region)[T.Новгородская область] -1168.3315   1298.732     -0.900      0.368   -3713.800    1377.137
# C(region)[T.Приморский край]       2406.9668   1264.740      1.903      0.057     -71.879    4885.812
# C(region)[T.Республика Алтай]      9109.9618   1450.879      6.279      0.000    6266.290     1.2e+04
# C(region)[T.Тульская область]      2275.7033   1003.624      2.267      0.023     308.637    4242.770
# C(region)[T.Хабаровский край]      1.423e+04   2537.830      5.607      0.000    9255.753    1.92e+04
# treatment_period                    667.8224   1913.577      0.349      0.727   -3082.720    4418.364
# treatment_1                       -1112.9125   1512.129     -0.736      0.462   -4076.632    1850.807
# treatment_period:treatment_1       -777.8473   2665.775     -0.292      0.770   -6002.670    4446.975
# ==============================================================================
# Omnibus:                       99.567   Durbin-Watson:                   1.215
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              804.999
# Skew:                           1.888   Prob(JB):                    1.57e-175
# Kurtosis:                      12.617   Cond. No.                         7.69
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %% [markdown]
# ### Models for difference

# %%
difference_roads_data = difference[["raion", "region", "treatment_1", "treatment_period", "roads"]].copy()
difference_roads_data.dropna(inplace=True)
difference_roads = sm_f.ols(formula="roads ~ treatment_period*treatment_1", data=difference_roads_data).fit(cov_type="cluster", cov_kwds={'groups': difference_roads_data['region']})
difference_roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  roads   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                     1.804
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.247
# Time:                        03:03:28   Log-Likelihood:                -1175.3
# No. Observations:                 140   AIC:                             2359.
# Df Residuals:                     136   BIC:                             2370.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      528.0907    187.943      2.810      0.005     159.730     896.452
# treatment_period               155.9613    187.963      0.830      0.407    -212.439     524.362
# treatment_1                   -322.2518    178.573     -1.805      0.071    -672.249      27.745
# treatment_period:treatment_1    75.0282    333.848      0.225      0.822    -579.301     729.358
# ==============================================================================
# Omnibus:                       93.447   Durbin-Watson:                   2.058
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              492.435
# Skew:                           2.496   Prob(JB):                    1.17e-107
# Kurtosis:                      10.714   Cond. No.                         7.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
difference_roads_data = difference[["raion", "region", "treatment_1", "treatment_period", "roads"]].copy()
difference_roads_data.dropna(inplace=True)
difference_roads = sm_f.ols(formula="roads ~ treatment_period*treatment_1 + C(region)", data=difference_roads_data).fit(cov_type="HC3")
difference_roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  roads   R-squared:                       0.107
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     2.124
# Date:                Wed, 10 May 2023   Prob (F-statistic):             0.0317
# Time:                        03:03:30   Log-Likelihood:                -1168.5
# No. Observations:                 140   AIC:                             2357.
# Df Residuals:                     130   BIC:                             2386.
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                           920.1428    321.030      2.866      0.004     290.936    1549.349
# C(region)[T.Мурманская область]     187.0566    819.280      0.228      0.819   -1418.702    1792.815
# C(region)[T.Новгородская область]  -773.8230    330.324     -2.343      0.019   -1421.247    -126.399
# C(region)[T.Приморский край]       -752.5495    318.752     -2.361      0.018   -1377.292    -127.807
# C(region)[T.Республика Алтай]      -226.7864    287.093     -0.790      0.430    -789.478     335.905
# C(region)[T.Тульская область]      -277.8672    417.776     -0.665      0.506   -1096.693     540.958
# C(region)[T.Хабаровский край]        -7.9282    315.964     -0.025      0.980    -627.206     611.349
# treatment_period                   -183.1990    322.012     -0.569      0.569    -814.330     447.932
# treatment_1                        -380.7048    261.409     -1.456      0.145    -893.058     131.648
# treatment_period:treatment_1        172.8896    494.447      0.350      0.727    -796.209    1141.988
# ==============================================================================
# Omnibus:                       80.453   Durbin-Watson:                   2.191
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              343.573
# Skew:                           2.161   Prob(JB):                     2.48e-75
# Kurtosis:                       9.342   Cond. No.                         8.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
difference_housing_data = difference[["raion", "region", "treatment_1", "treatment_period", "housing"]].copy()
difference_housing_data.dropna(inplace=True)
difference_housing = sm_f.ols(formula="housing ~ treatment_period*treatment_1", data=difference_housing_data).fit(cov_type="cluster", cov_kwds={'groups': difference_housing_data['region']})
difference_housing.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                housing   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.016
# Method:                 Least Squares   F-statistic:                     106.5
# Date:                Wed, 10 May 2023   Prob (F-statistic):           1.36e-05
# Time:                        03:03:33   Log-Likelihood:                -1461.2
# No. Observations:                 146   AIC:                             2930.
# Df Residuals:                     142   BIC:                             2942.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      678.3971    680.205      0.997      0.319    -654.780    2011.574
# treatment_period               827.1276    693.315      1.193      0.233    -531.745    2186.000
# treatment_1                    631.3809    872.474      0.724      0.469   -1078.636    2341.398
# treatment_period:treatment_1 -1666.2556    836.363     -1.992      0.046   -3305.497     -27.014
# ==============================================================================
# Omnibus:                      175.497   Durbin-Watson:                   1.763
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10723.520
# Skew:                          -4.210   Prob(JB):                         0.00
# Kurtosis:                      44.132   Cond. No.                         7.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
difference_housing_data = difference[["raion", "region", "treatment_1", "treatment_period", "housing"]].copy()
difference_housing_data.dropna(inplace=True)
difference_housing = sm_f.ols(formula="housing ~ treatment_period*treatment_1 + C(region)", data=difference_housing_data).fit(cov_type="HC3")
difference_housing.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                housing   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                 -0.030
# Method:                 Least Squares   F-statistic:                     1.490
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.158
# Time:                        03:03:35   Log-Likelihood:                -1459.1
# No. Observations:                 146   AIC:                             2938.
# Df Residuals:                     136   BIC:                             2968.
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          -599.6980   2865.566     -0.209      0.834   -6216.104    5016.708
# C(region)[T.Мурманская область]    1357.0054   2784.776      0.487      0.626   -4101.056    6815.066
# C(region)[T.Новгородская область]  1050.5602   2860.003      0.367      0.713   -4554.943    6656.064
# C(region)[T.Приморский край]        719.3300   2761.724      0.260      0.795   -4693.550    6132.210
# C(region)[T.Республика Алтай]      2146.5636   1971.961      1.089      0.276   -1718.409    6011.536
# C(region)[T.Тульская область]      2204.3484   2713.969      0.812      0.417   -3114.933    7523.630
# C(region)[T.Хабаровский край]      2515.8962   2358.883      1.067      0.286   -2107.430    7139.223
# treatment_period                    405.0858   1826.579      0.222      0.824   -3174.944    3985.115
# treatment_1                         553.8629    765.279      0.724      0.469    -946.057    2053.782
# treatment_period:treatment_1      -1250.4053   1175.415     -1.064      0.287   -3554.176    1053.366
# ==============================================================================
# Omnibus:                      174.994   Durbin-Watson:                   1.813
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9760.017
# Skew:                          -4.236   Prob(JB):                         0.00
# Kurtosis:                      42.149   Cond. No.                         8.79
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
difference_education_data = difference[["raion", "region", "treatment_1", "treatment_period", "education"]].copy()
difference_education_data.dropna(inplace=True)
difference_education = sm_f.ols(formula="education ~ treatment_period*treatment_1", data=difference_education_data).fit(cov_type="cluster", cov_kwds={'groups': difference_education_data['region']})
difference_education.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              education   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     1.780
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.251
# Time:                        03:03:37   Log-Likelihood:                -1487.0
# No. Observations:                 151   AIC:                             2982.
# Df Residuals:                     147   BIC:                             2994.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     2969.4054   1450.198      2.048      0.041     127.070    5811.740
# treatment_period              1661.3760   1732.938      0.959      0.338   -1735.120    5057.872
# treatment_1                   -963.8444    649.583     -1.484      0.138   -2237.003     309.314
# treatment_period:treatment_1   281.4395   1946.420      0.145      0.885   -3533.474    4096.353
# ==============================================================================
# Omnibus:                       81.045   Durbin-Watson:                   1.483
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              299.145
# Skew:                           2.115   Prob(JB):                     1.10e-65
# Kurtosis:                       8.445   Cond. No.                         7.38
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
difference_education_data = difference[["raion", "region", "treatment_1", "treatment_period", "education"]].copy()
difference_education_data.dropna(inplace=True)
difference_education = sm_f.ols(formula="education ~ treatment_period*treatment_1 + C(region)", data=difference_education_data).fit(cov_type="HC3")
difference_education.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              education   R-squared:                       0.263
# Model:                            OLS   Adj. R-squared:                  0.216
# Method:                 Least Squares   F-statistic:                     12.01
# Date:                Wed, 10 May 2023   Prob (F-statistic):           6.06e-14
# Time:                        03:03:39   Log-Likelihood:                -1466.4
# No. Observations:                 151   AIC:                             2953.
# Df Residuals:                     141   BIC:                             2983.
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          7298.9050   1037.474      7.035      0.000    5265.494    9332.316
# C(region)[T.Мурманская область]   -6531.2337   1024.329     -6.376      0.000   -8538.882   -4523.586
# C(region)[T.Новгородская область] -5739.3979   1220.557     -4.702      0.000   -8131.645   -3347.151
# C(region)[T.Приморский край]      -7048.2675   1024.873     -6.877      0.000   -9056.981   -5039.554
# C(region)[T.Республика Алтай]     -1872.5194   1157.335     -1.618      0.106   -4140.854     395.816
# C(region)[T.Тульская область]     -4725.0392   1427.392     -3.310      0.001   -7522.676   -1927.402
# C(region)[T.Хабаровский край]     -2943.0881   1324.255     -2.222      0.026   -5538.580    -347.596
# treatment_period                   -860.4163   1189.448     -0.723      0.469   -3191.691    1470.858
# treatment_1                        -441.3437    800.492     -0.551      0.581   -2010.278    1127.591
# treatment_period:treatment_1       -711.1432   2789.396     -0.255      0.799   -6178.259    4755.973
# ==============================================================================
# Omnibus:                      100.306   Durbin-Watson:                   1.783
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              813.725
# Skew:                           2.304   Prob(JB):                    2.00e-177
# Kurtosis:                      13.397   Cond. No.                         8.33
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %% [markdown]
# # Goods t-1

# %%
with open("D:/DZ/Course_6/Diploma/Data/full_ind_data.csv", "rb") as inp:
    full_ind_data = pickle.load(inp)

# %%
with open("D:/DZ/Course_6/Diploma/Data/mun_data_25.csv", "rb") as inp:
    mun_data = pd.read_csv(inp, index_col=0)

# %%
mun_data.reset_index(inplace=True, drop=True)

# %%
full_ind_data.shape
# Out:
# (1386, 14)

# %%
full_ind_data.head()
# Out:
#              raion           region  treatment_1  treatment_2  year  \
# 0  Владивостокский  Приморский край            1            1  2013
# 1  Владивостокский  Приморский край            1            1  2014
# 2  Владивостокский  Приморский край            1            1  2015
# 3  Владивостокский  Приморский край            1            1  2016
# 4  Владивостокский  Приморский край            1            1  2017
#
#    bad_roads  bad_schools  unfinished_construction  housing  population  \
# 0        NaN          NaN                  3400.00     4.05    625868.0
# 1        NaN          NaN                  3400.00     3.88    630027.0
# 2        NaN          0.0                 21529.93     5.00    631387.0
# 3        NaN          0.0                  2411.41     5.17    633167.0
# 4        NaN          0.0                      NaN     3.19    633414.0
#
#    lack_transportation  heat_grid_fixed  water_grid_fixed  sewage_grid_fixed
# 0                  NaN         0.050240          0.004470           0.001211
# 1                  NaN         0.020670          0.008552           0.004417
# 2                  NaN         0.019753          0.009448           0.003201
# 3                  NaN         0.011566          0.006601           0.001074
# 4                  NaN         0.013158          0.003128           0.003201

# %%
full_in_data = pd.merge(full_ind_data, mun_data, on=["raion", "region"], how="left")

# %%
full_ind_data = full_in_data.drop(columns=["treatment_1_x", "treatment_2_x"]).rename(columns={"treatment_1_y": "treatment_1", "treatment_2_y": "treatment_2"})

# %%
full_ind_data.shape
# Out:
# (1386, 14)

# %%
full_ind_data.head()
# Out:
#              raion           region  year  bad_roads  bad_schools  \
# 0  Владивостокский  Приморский край  2013        NaN          NaN
# 1  Владивостокский  Приморский край  2014        NaN          NaN
# 2  Владивостокский  Приморский край  2015        NaN          0.0
# 3  Владивостокский  Приморский край  2016        NaN          0.0
# 4  Владивостокский  Приморский край  2017        NaN          0.0
#
#    unfinished_construction  housing  population  lack_transportation  \
# 0                  3400.00     4.05    625868.0                  NaN
# 1                  3400.00     3.88    630027.0                  NaN
# 2                 21529.93     5.00    631387.0                  NaN
# 3                  2411.41     5.17    633167.0                  NaN
# 4                      NaN     3.19    633414.0                  NaN
#
#    heat_grid_fixed  water_grid_fixed  sewage_grid_fixed  treatment_1  \
# 0         0.050240          0.004470           0.001211            0
# 1         0.020670          0.008552           0.004417            0
# 2         0.019753          0.009448           0.003201            0
# 3         0.011566          0.006601           0.001074            0
# 4         0.013158          0.003128           0.003201            0
#
#    treatment_2
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
two_time_points = pd.DataFrame()
for i in mapping.keys():
    two_time_points = two_time_points.append(full_ind_data.loc[(full_ind_data.region == i) & ((full_ind_data.year == mapping[i]) | (full_ind_data.year == mapping[i] + 4))])

two_time_points.reset_index(inplace=True, drop=True)

two_time_points["treatment_period"] = [1 if i > 2018 else 0 for i in two_time_points.year]

# %%
treat_1_roads = two_time_points[["raion", "region", "treatment_1", "treatment_period", "bad_roads"]].copy()
treat_1_roads.dropna(inplace=True)

roads = sm_f.ols(formula="bad_roads ~ treatment_period*treatment_1", data=treat_1_roads).fit(cov_type="cluster", cov_kwds={'groups': treat_1_roads['region']})
roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              bad_roads   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.4136
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.750
# Time:                        03:03:53   Log-Likelihood:                -993.23
# No. Observations:                 212   AIC:                             1994.
# Df Residuals:                     208   BIC:                             2008.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       56.9690      8.314      6.852      0.000      40.673      73.265
# treatment_period                -5.3190      8.462     -0.629      0.530     -21.905      11.267
# treatment_1                     -1.6416      7.346     -0.223      0.823     -16.040      12.757
# treatment_period:treatment_1    -4.8384     10.005     -0.484      0.629     -24.447      14.770
# ==============================================================================
# Omnibus:                       27.074   Durbin-Watson:                   0.954
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                9.650
# Skew:                          -0.253   Prob(JB):                      0.00803
# Kurtosis:                       2.086   Cond. No.                         7.28
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
treat_1_roads = two_time_points[["raion", "region", "treatment_1", "treatment_period", "bad_roads"]].copy()
treat_1_roads.dropna(inplace=True)

roads = sm_f.ols(formula="bad_roads ~ treatment_period*treatment_1 + C(region)", data=treat_1_roads).fit(cov_type="HC3")
roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              bad_roads   R-squared:                       0.346
# Model:                            OLS   Adj. R-squared:                  0.317
# Method:                 Least Squares   F-statistic:                     12.00
# Date:                Wed, 10 May 2023   Prob (F-statistic):           4.23e-15
# Time:                        03:03:55   Log-Likelihood:                -949.49
# No. Observations:                 212   AIC:                             1919.
# Df Residuals:                     202   BIC:                             1953.
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            57.8073      4.411     13.105      0.000      49.162      66.453
# C(region)[T.Мурманская область]     -19.3670      6.294     -3.077      0.002     -31.703      -7.031
# C(region)[T.Новгородская область]    -4.2775      4.962     -0.862      0.389     -14.003       5.448
# C(region)[T.Республика Алтай]        22.4567      6.570      3.418      0.001       9.580      35.333
# C(region)[T.Республика Марий Эл]     16.5597      5.539      2.989      0.003       5.703      27.417
# C(region)[T.Тульская область]        -4.8478      5.765     -0.841      0.400     -16.148       6.452
# C(region)[T.Хабаровский край]       -30.6815      6.765     -4.535      0.000     -43.941     -17.422
# treatment_period                     -0.6285      4.811     -0.131      0.896     -10.058       8.801
# treatment_1                          -2.9267      5.706     -0.513      0.608     -14.111       8.258
# treatment_period:treatment_1         -2.9376      9.254     -0.317      0.751     -21.075      15.200
# ==============================================================================
# Omnibus:                        2.079   Durbin-Watson:                   1.439
# Prob(Omnibus):                  0.354   Jarque-Bera (JB):                1.743
# Skew:                          -0.138   Prob(JB):                        0.418
# Kurtosis:                       3.348   Cond. No.                         7.96
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
treat_1_schools = two_time_points[["raion", "region", "treatment_1", "treatment_period", "bad_schools"]].copy()
treat_1_schools.dropna(inplace=True)

schools = sm_f.ols(formula="bad_schools ~ treatment_period*treatment_1", data=treat_1_schools).fit(cov_type="cluster", cov_kwds={'groups': treat_1_schools['region']})
schools.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            bad_schools   R-squared:                       0.146
# Model:                            OLS   Adj. R-squared:                  0.127
# Method:                 Least Squares   F-statistic:                     22.21
# Date:                Wed, 10 May 2023   Prob (F-statistic):           0.000594
# Time:                        03:03:58   Log-Likelihood:                -506.56
# No. Observations:                 139   AIC:                             1021.
# Df Residuals:                     135   BIC:                             1033.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        2.9587      1.163      2.544      0.011       0.679       5.238
# treatment_period                16.0413      3.762      4.265      0.000       8.669      23.414
# treatment_1                      1.4813      1.526      0.971      0.332      -1.509       4.471
# treatment_period:treatment_1    -8.4813      3.999     -2.121      0.034     -16.319      -0.643
# ==============================================================================
# Omnibus:                      115.715   Durbin-Watson:                   2.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              890.029
# Skew:                           3.129   Prob(JB):                    5.40e-194
# Kurtosis:                      13.702   Cond. No.                         10.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
treat_1_schools = two_time_points[["raion", "region", "treatment_1", "treatment_period", "bad_schools"]].copy()
treat_1_schools.dropna(inplace=True)

schools = sm_f.ols(formula="bad_schools ~ treatment_period*treatment_1 + C(region)", data=treat_1_schools).fit(cov_type="HC3")
schools.summary()
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\regression\linear_model.py:1908: RuntimeWarning: divide by zero encountered in true_divide
#   self.het_scale = (self.wresid / (1 - h))**2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-30a7905a6ab2> in <module>
#       3
#       4 schools = sm_f.ols(formula="bad_schools ~ treatment_period*treatment_1 + C(region)", data=treat_1_schools).fit(cov_type="HC3")
# ----> 5 schools.summary()
#
# D:\Anaconda\lib\site-packages\statsmodels\regression\linear_model.py in summary(self, yname, xname, title, alpha)
#    2641                      ('Adj. R-squared' + rsquared_type + ':',
#    2642                       ["%#8.3f" % self.rsquared_adj]),
# -> 2643                      ('F-statistic:', ["%#8.4g" % self.fvalue]),
#    2644                      ('Prob (F-statistic):', ["%#6.3g" % self.f_pvalue]),
#    2645                      ('Log-Likelihood:', None),
#
# pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# D:\Anaconda\lib\site-packages\statsmodels\regression\linear_model.py in fvalue(self)
#    1796                 if mat.size == 0:  # see  #3642
#    1797                     return np.nan
# -> 1798             ft = self.f_test(mat)
#    1799             # using backdoor to set another attribute that we already have
#    1800             self._cache['f_pvalue'] = float(ft.pvalue)
#
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py in f_test(self, r_matrix, cov_p, scale, invcov)
#    1723                           DeprecationWarning)
#    1724
# -> 1725         res = self.wald_test(r_matrix, cov_p=cov_p, invcov=invcov, use_f=True)
#    1726         return res
#    1727
#
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py in wald_test(self, r_matrix, cov_p, scale, invcov, use_f, df_constraints)
#    1824             cov_p = self.cov_params(r_matrix=r_matrix, cov_p=cov_p)
#    1825             if np.isnan(cov_p).max():
# -> 1826                 raise ValueError("r_matrix performs f_test for using "
#    1827                                  "dimensions that are asymptotically "
#    1828                                  "non-normal")
#
# ValueError: r_matrix performs f_test for using dimensions that are asymptotically non-normal

# %%
treat_1_sewerage = two_time_points[["raion", "region", "treatment_1", "treatment_period", "sewage_grid_fixed"]].copy()
treat_1_sewerage.dropna(inplace=True)

sewerage = sm_f.ols(formula="sewage_grid_fixed ~ treatment_period*treatment_1", data=treat_1_sewerage).fit(cov_type="cluster", cov_kwds={'groups': treat_1_sewerage['region']})
sewerage.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      sewage_grid_fixed   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                 -0.016
# Method:                 Least Squares   F-statistic:                     3.543
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.103
# Time:                        03:04:20   Log-Likelihood:                 121.42
# No. Observations:                 107   AIC:                            -234.8
# Df Residuals:                     103   BIC:                            -224.1
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.0144      0.004      3.314      0.001       0.006       0.023
# treatment_period                 0.0193      0.018      1.086      0.277      -0.015       0.054
# treatment_1                      0.0076      0.010      0.791      0.429      -0.011       0.026
# treatment_period:treatment_1    -0.0323      0.026     -1.220      0.223      -0.084       0.020
# ==============================================================================
# Omnibus:                      196.450   Durbin-Watson:                   1.530
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20023.992
# Skew:                           7.666   Prob(JB):                         0.00
# Kurtosis:                      68.240   Cond. No.                         6.72
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
treat_1_sewerage = two_time_points[["raion", "region", "treatment_1", "treatment_period", "sewage_grid_fixed"]].copy()
treat_1_sewerage.dropna(inplace=True)

sewerage = sm_f.ols(formula="sewage_grid_fixed ~ treatment_period*treatment_1 + C(region)", data=treat_1_sewerage).fit(cov_type="HC3")
sewerage.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      sewage_grid_fixed   R-squared:                       0.061
# Model:                            OLS   Adj. R-squared:                 -0.016
# Method:                 Least Squares   F-statistic:                    0.9219
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.502
# Time:                        03:04:21   Log-Likelihood:                 124.10
# No. Observations:                 107   AIC:                            -230.2
# Df Residuals:                      98   BIC:                            -206.1
# Df Model:                           8
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.0059      0.007      0.807      0.420      -0.008       0.020
# C(region)[T.Мурманская область]      -0.0023      0.013     -0.174      0.862      -0.028       0.023
# C(region)[T.Новгородская область]     0.0043      0.015      0.287      0.774      -0.025       0.034
# C(region)[T.Приморский край]          0.0418      0.023      1.807      0.071      -0.004       0.087
# C(region)[T.Тульская область]        -0.0012      0.008     -0.165      0.869      -0.016       0.014
# C(region)[T.Хабаровский край]         0.0033      0.007      0.464      0.643      -0.011       0.017
# treatment_period                      0.0060      0.024      0.244      0.807      -0.042       0.054
# treatment_1                           0.0079      0.015      0.541      0.589      -0.021       0.036
# treatment_period:treatment_1         -0.0261      0.028     -0.937      0.349      -0.081       0.028
# ==============================================================================
# Omnibus:                      193.269   Durbin-Watson:                   1.626
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            19225.927
# Skew:                           7.430   Prob(JB):                         0.00
# Kurtosis:                      66.965   Cond. No.                         15.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
treat_1_heat = two_time_points[["raion", "region", "treatment_1", "treatment_period", "heat_grid_fixed"]].copy()
treat_1_heat.dropna(inplace=True)

heat = sm_f.ols(formula="heat_grid_fixed ~ treatment_period*treatment_1", data=treat_1_heat).fit(cov_type="HC3") # т.к. в выборке только один регион
heat.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        heat_grid_fixed   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                 -0.027
# Method:                 Least Squares   F-statistic:                     1.133
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.344
# Time:                        03:04:22   Log-Likelihood:                 121.10
# No. Observations:                  58   AIC:                            -234.2
# Df Residuals:                      54   BIC:                            -226.0
# Df Model:                           3
# Covariance Type:                  HC3
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.0242      0.004      6.614      0.000       0.017       0.031
# treatment_period                 0.0086      0.010      0.849      0.396      -0.011       0.028
# treatment_1                      0.0018      0.009      0.201      0.840      -0.016       0.019
# treatment_period:treatment_1    -0.0172      0.013     -1.273      0.203      -0.044       0.009
# ==============================================================================
# Omnibus:                       99.163   Durbin-Watson:                   2.112
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2384.305
# Skew:                           5.046   Prob(JB):                         0.00
# Kurtosis:                      32.745   Cond. No.                         7.10
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
treat_1_water = two_time_points[["raion", "region", "treatment_1", "treatment_period", "water_grid_fixed"]].copy()
treat_1_water.dropna(inplace=True)

water = sm_f.ols(formula="water_grid_fixed ~ treatment_period*treatment_1", data=treat_1_water).fit(cov_type="cluster", cov_kwds={'groups': treat_1_water['region']})
water.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       water_grid_fixed   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                    0.7495
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.568
# Time:                        03:04:22   Log-Likelihood:                 226.90
# No. Observations:                 158   AIC:                            -445.8
# Df Residuals:                     154   BIC:                            -433.6
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.0276      0.011      2.631      0.009       0.007       0.048
# treatment_period                -0.0091      0.008     -1.195      0.232      -0.024       0.006
# treatment_1                     -0.0125      0.012     -1.020      0.308      -0.036       0.011
# treatment_period:treatment_1     0.0153      0.011      1.348      0.178      -0.007       0.038
# ==============================================================================
# Omnibus:                      301.092   Durbin-Watson:                   1.667
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            74179.031
# Skew:                           9.557   Prob(JB):                         0.00
# Kurtosis:                     107.414   Cond. No.                         7.15
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
treat_1_water = two_time_points[["raion", "region", "treatment_1", "treatment_period", "water_grid_fixed"]].copy()
treat_1_water.dropna(inplace=True)

water = sm_f.ols(formula="water_grid_fixed ~ treatment_period*treatment_1 + C(region)", data=treat_1_water).fit(cov_type="HC3")
water.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       water_grid_fixed   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     3.905
# Date:                Wed, 10 May 2023   Prob (F-statistic):           0.000328
# Time:                        03:04:23   Log-Likelihood:                 233.87
# No. Observations:                 158   AIC:                            -449.7
# Df Residuals:                     149   BIC:                            -422.2
# Df Model:                           8
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.0138      0.004      3.473      0.001       0.006       0.022
# C(region)[T.Мурманская область]       0.0528      0.038      1.379      0.168      -0.022       0.128
# C(region)[T.Новгородская область] -2.618e-05      0.007     -0.004      0.997      -0.014       0.014
# C(region)[T.Приморский край]          0.0128      0.008      1.635      0.102      -0.003       0.028
# C(region)[T.Республика Алтай]         0.0041      0.006      0.680      0.497      -0.008       0.016
# C(region)[T.Хабаровский край]         0.0208      0.007      3.100      0.002       0.008       0.034
# treatment_period                     -0.0115      0.015     -0.782      0.434      -0.040       0.017
# treatment_1                          -0.0159      0.013     -1.198      0.231      -0.042       0.010
# treatment_period:treatment_1          0.0127      0.015      0.850      0.395      -0.017       0.042
# ==============================================================================
# Omnibus:                      291.458   Durbin-Watson:                   1.812
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            64383.104
# Skew:                           8.981   Prob(JB):                         0.00
# Kurtosis:                     100.247   Cond. No.                         9.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %% [markdown]
# # Fin t-1

# %%
with open("D:/DZ/Course_6/Diploma/Data/financial_data.csv", "rb") as inp:
    temp_fin = pickle.load(inp)

# %%
with open("D:/DZ/Course_6/Diploma/Data/mun_data_25.csv", "rb") as inp:
    data_for_models = pd.read_csv(inp, index_col=0)

# %%
mapping = {"Приморский край": 2016, "Мурманская область": 2016, "Костромская область": 2015, "Республика Алтай": 2014, "Республика Марий Эл": 2014, "Хабаровский край": 2014, 
           "Тульская область": 2014, "Новгородская область": 2016}

# %%
actual, initial, difference = temp_fin.loc[temp_fin.budget_type == "actual_spending"], temp_fin.loc[temp_fin.budget_type == "initial_budget"], temp_fin.loc[temp_fin.budget_type == "разница"]

# %%
actual = pd.pivot(actual, index = ["region", "raion", "year"], columns="sub_indicator", values="values").reset_index()
initial = pd.pivot(initial, index = ["region", "raion", "year"], columns="sub_indicator", values="values").reset_index()
difference = pd.pivot(difference, index = ["region", "raion", "year"], columns="sub_indicator", values="values").reset_index()

# %%
for i in actual, initial, difference:
    i.rename(columns={"дорожное хозяйство (дорожные фонды)": "roads", "жилищно-коммунальное хозяйство": "housing", "образование": "education"}, inplace=True)

# %%
actual.head()
# Out:
# sub_indicator               region               raion  year       roads  \
# 0              Костромская область  Антроповский район  2013  666.115702
# 1              Костромская область  Антроповский район  2014  603.232937
# 2              Костромская область  Антроповский район  2015  688.908710
# 3              Костромская область  Антроповский район  2016  764.043811
# 4              Костромская область  Антроповский район  2017         NaN
#
# sub_indicator      housing     education
# 0              1610.368144  12882.945154
# 1              1922.796250  12638.114480
# 2                95.255228  21901.154847
# 3               203.425719  10986.123190
# 4                      NaN           NaN

# %%
frames = [actual, initial, difference]

# %%
for i in range(len(frames)):
    temp_fin_data = pd.DataFrame()
    for j in mapping.keys():
        temp_fin_data = temp_fin_data.append(frames[i].loc[(frames[i].region == j) & ((frames[i].year == mapping[j]) | (frames[i].year == mapping[j] + 4))])
    temp_fin_data["treatment_period"] = [1 if i > 2018 else 0 for i in temp_fin_data.year]
    frames[i] = pd.merge(temp_fin_data, data_for_models, on=["region", "raion"], how="inner")

# %%
#frames[0]

# %%
actual, initial, difference = frames

# %% [markdown]
# ### Models for actual budgets

# %%
actual_roads_data = actual[["raion", "region", "treatment_1", "treatment_period", "roads"]].copy()
actual_roads_data.dropna(inplace=True)
actual_roads = sm_f.ols(formula="roads ~ treatment_period*treatment_1", data=actual_roads_data).fit(cov_type="cluster", cov_kwds={'groups': actual_roads_data['region']})
actual_roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  roads   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     3.927
# Date:                Wed, 10 May 2023   Prob (F-statistic):             0.0619
# Time:                        03:04:32   Log-Likelihood:                -2313.5
# No. Observations:                 268   AIC:                             4635.
# Df Residuals:                     264   BIC:                             4649.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1037.6948    141.359      7.341      0.000     760.635    1314.754
# treatment_period               499.0814    262.807      1.899      0.058     -16.012    1014.174
# treatment_1                    435.5114    292.835      1.487      0.137    -138.434    1009.457
# treatment_period:treatment_1  -665.2872    315.912     -2.106      0.035   -1284.464     -46.111
# ==============================================================================
# Omnibus:                      117.441   Durbin-Watson:                   1.813
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              379.779
# Skew:                           1.965   Prob(JB):                     3.40e-83
# Kurtosis:                       7.309   Cond. No.                         7.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
actual_roads_data = actual[["raion", "region", "treatment_1", "treatment_period", "roads"]].copy()
actual_roads_data.dropna(inplace=True)
actual_roads = sm_f.ols(formula="roads ~ treatment_period*treatment_1 + C(region)", data=actual_roads_data).fit(cov_type="HC3")
actual_roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  roads   R-squared:                       0.147
# Model:                            OLS   Adj. R-squared:                  0.114
# Method:                 Least Squares   F-statistic:                     6.321
# Date:                Wed, 10 May 2023   Prob (F-statistic):           1.13e-08
# Time:                        03:04:33   Log-Likelihood:                -2295.8
# No. Observations:                 268   AIC:                             4614.
# Df Residuals:                     257   BIC:                             4653.
# Df Model:                          10
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          1100.0484    281.506      3.908      0.000     548.306    1651.791
# C(region)[T.Мурманская область]     923.6299    607.564      1.520      0.128    -267.174    2114.433
# C(region)[T.Новгородская область]  -868.0090    315.189     -2.754      0.006   -1485.768    -250.250
# C(region)[T.Приморский край]       -415.0896    288.322     -1.440      0.150    -980.191     150.011
# C(region)[T.Республика Алтай]       658.0857    446.847      1.473      0.141    -217.719    1533.890
# C(region)[T.Республика Марий Эл]   -352.7350    315.457     -1.118      0.263    -971.020     265.550
# C(region)[T.Тульская область]       364.1695    419.606      0.868      0.385    -458.244    1186.583
# C(region)[T.Хабаровский край]       209.2295    365.957      0.572      0.568    -508.033     926.492
# treatment_period                    865.5629    230.047      3.763      0.000     414.679    1316.446
# treatment_1                         191.8445    307.073      0.625      0.532    -410.008     793.696
# treatment_period:treatment_1       -561.9087    539.598     -1.041      0.298   -1619.500     495.683
# ==============================================================================
# Omnibus:                      121.541   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              441.012
# Skew:                           1.977   Prob(JB):                     1.72e-96
# Kurtosis:                       7.885   Cond. No.                         9.96
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
actual_housing_data = actual[["raion", "region", "treatment_1", "treatment_period", "housing"]].copy()
actual_housing_data.dropna(inplace=True)
actual_housing = sm_f.ols(formula="housing ~ treatment_period*treatment_1", data=actual_housing_data).fit(cov_type="cluster", cov_kwds={'groups': actual_housing_data['region']})
actual_housing.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                housing   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     1.296
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.349
# Time:                        03:04:33   Log-Likelihood:                -2821.5
# No. Observations:                 265   AIC:                             5651.
# Df Residuals:                     261   BIC:                             5665.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     4797.9104   3050.288      1.573      0.116   -1180.544    1.08e+04
# treatment_period             -2960.1122   3069.052     -0.965      0.335   -8975.343    3055.119
# treatment_1                  -2854.9541   2998.140     -0.952      0.341   -8731.201    3021.293
# treatment_period:treatment_1  2466.9866   2998.244      0.823      0.411   -3409.464    8343.437
# ==============================================================================
# Omnibus:                      361.994   Durbin-Watson:                   1.121
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            26982.882
# Skew:                           6.476   Prob(JB):                         0.00
# Kurtosis:                      50.707   Cond. No.                         7.77
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
actual_housing_data = actual[["raion", "region", "treatment_1", "treatment_period", "housing"]].copy()
actual_housing_data.dropna(inplace=True)
actual_housing = sm_f.ols(formula="housing ~ treatment_period*treatment_1 + C(region)", data=actual_housing_data).fit(cov_type="HC3")
actual_housing.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                housing   R-squared:                       0.261
# Model:                            OLS   Adj. R-squared:                  0.232
# Method:                 Least Squares   F-statistic:                     8.693
# Date:                Wed, 10 May 2023   Prob (F-statistic):           3.16e-12
# Time:                        03:04:34   Log-Likelihood:                -2783.9
# No. Observations:                 265   AIC:                             5590.
# Df Residuals:                     254   BIC:                             5629.
# Df Model:                          10
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          2494.0228    519.963      4.797      0.000    1474.915    3513.131
# C(region)[T.Мурманская область]    1099.3577    676.826      1.624      0.104    -227.197    2425.912
# C(region)[T.Новгородская область] -2380.0568    532.099     -4.473      0.000   -3422.952   -1337.161
# C(region)[T.Приморский край]      -1403.7215    490.804     -2.860      0.004   -2365.679    -441.764
# C(region)[T.Республика Алтай]       222.9808    649.485      0.343      0.731   -1049.986    1495.948
# C(region)[T.Республика Марий Эл]  -1175.2700    539.401     -2.179      0.029   -2232.476    -118.064
# C(region)[T.Тульская область]       412.4794    695.467      0.593      0.553    -950.610    1775.569
# C(region)[T.Хабаровский край]      1.395e+04   3839.826      3.634      0.000    6428.350    2.15e+04
# treatment_period                    765.4420    286.135      2.675      0.007     204.627    1326.257
# treatment_1                       -1296.8910    899.690     -1.441      0.149   -3060.251     466.470
# treatment_period:treatment_1        672.8720    993.892      0.677      0.498   -1275.121    2620.865
# ==============================================================================
# Omnibus:                      340.454   Durbin-Watson:                   1.435
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            24229.844
# Skew:                           5.790   Prob(JB):                         0.00
# Kurtosis:                      48.391   Cond. No.                         10.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
actual_education_data = actual[["raion", "region", "treatment_1", "treatment_period", "education"]].copy()
actual_education_data.dropna(inplace=True)
actual_education = sm_f.ols(formula="education ~ treatment_period*treatment_1", data=actual_education_data).fit(cov_type="cluster", cov_kwds={'groups': actual_education_data['region']})
actual_education.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              education   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     3.778
# Date:                Wed, 10 May 2023   Prob (F-statistic):             0.0671
# Time:                        03:04:34   Log-Likelihood:                -2812.0
# No. Observations:                 268   AIC:                             5632.
# Df Residuals:                     264   BIC:                             5646.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1.574e+04   3200.758      4.918      0.000    9468.121     2.2e+04
# treatment_period             -1845.2413   3276.454     -0.563      0.573   -8266.973    4576.490
# treatment_1                  -2923.2889   3150.704     -0.928      0.354   -9098.555    3251.978
# treatment_period:treatment_1  5322.9111   3351.732      1.588      0.112   -1246.363    1.19e+04
# ==============================================================================
# Omnibus:                      170.145   Durbin-Watson:                   0.833
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1334.459
# Skew:                           2.540   Prob(JB):                    1.68e-290
# Kurtosis:                      12.680   Cond. No.                         7.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
actual_education_data = actual[["raion", "region", "treatment_1", "treatment_period", "education"]].copy()
actual_education_data.dropna(inplace=True)
actual_education = sm_f.ols(formula="education ~ treatment_period*treatment_1 + C(region)", data=actual_education_data).fit(cov_type="HC3")
actual_education.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              education   R-squared:                       0.442
# Model:                            OLS   Adj. R-squared:                  0.420
# Method:                 Least Squares   F-statistic:                     35.70
# Date:                Wed, 10 May 2023   Prob (F-statistic):           3.55e-43
# Time:                        03:04:34   Log-Likelihood:                -2736.0
# No. Observations:                 268   AIC:                             5494.
# Df Residuals:                     257   BIC:                             5534.
# Df Model:                          10
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          1.676e+04   1119.170     14.978      0.000    1.46e+04     1.9e+04
# C(region)[T.Мурманская область]    2911.9592   1314.709      2.215      0.027     335.177    5488.742
# C(region)[T.Новгородская область] -7593.9990   1283.215     -5.918      0.000   -1.01e+04   -5078.944
# C(region)[T.Приморский край]      -4950.1812   1218.630     -4.062      0.000   -7338.652   -2561.710
# C(region)[T.Республика Алтай]      4177.1239   1611.404      2.592      0.010    1018.831    7335.417
# C(region)[T.Республика Марий Эл]  -7612.1504   1169.586     -6.508      0.000   -9904.496   -5319.805
# C(region)[T.Тульская область]     -4990.2046   1248.950     -3.996      0.000   -7438.102   -2542.307
# C(region)[T.Хабаровский край]      9422.2696   2643.085      3.565      0.000    4241.919    1.46e+04
# treatment_period                   1925.6685    832.555      2.313      0.021     293.891    3557.446
# treatment_1                       -1790.9035   1157.735     -1.547      0.122   -4060.023     478.216
# treatment_period:treatment_1       3603.2257   2558.547      1.408      0.159   -1411.434    8617.885
# ==============================================================================
# Omnibus:                      168.834   Durbin-Watson:                   1.249
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1789.976
# Skew:                           2.371   Prob(JB):                         0.00
# Kurtosis:                      14.739   Cond. No.                         9.96
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %% [markdown]
# ### Models for initial budgets

# %%
initial_roads_data = initial[["raion", "region", "treatment_1", "treatment_period", "roads"]].copy()
initial_roads_data.dropna(inplace=True)
initial_roads = sm_f.ols(formula="roads ~ treatment_period*treatment_1", data=initial_roads_data).fit(cov_type="cluster", cov_kwds={'groups': initial_roads_data['region']})
initial_roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  roads   R-squared:                       0.028
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     4.574
# Date:                Wed, 10 May 2023   Prob (F-statistic):             0.0541
# Time:                        03:04:35   Log-Likelihood:                -2097.7
# No. Observations:                 225   AIC:                             4203.
# Df Residuals:                     221   BIC:                             4217.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      478.2795     72.368      6.609      0.000     336.441     620.118
# treatment_period              1027.7826    560.294      1.834      0.067     -70.373    2125.938
# treatment_1                    431.5259    176.441      2.446      0.014      85.709     777.343
# treatment_period:treatment_1  -865.9794    371.190     -2.333      0.020   -1593.499    -138.460
# ==============================================================================
# Omnibus:                      466.999   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           297388.201
# Skew:                          12.685   Prob(JB):                         0.00
# Kurtosis:                     179.289   Cond. No.                         6.72
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
initial_roads_data = initial[["raion", "region", "treatment_1", "treatment_period", "roads"]].copy()
initial_roads_data.dropna(inplace=True)
initial_roads = sm_f.ols(formula="roads ~ treatment_period*treatment_1 + C(region)", data=initial_roads_data).fit(cov_type="HC3")
initial_roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  roads   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     4.094
# Date:                Wed, 10 May 2023   Prob (F-statistic):           7.15e-05
# Time:                        03:04:35   Log-Likelihood:                -2094.8
# No. Observations:                 225   AIC:                             4210.
# Df Residuals:                     215   BIC:                             4244.
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          1082.1079    695.173      1.557      0.120    -280.406    2444.621
# C(region)[T.Мурманская область]    -156.9521    950.382     -0.165      0.869   -2019.666    1705.762
# C(region)[T.Новгородская область] -1253.9984    950.708     -1.319      0.187   -3117.351     609.354
# C(region)[T.Приморский край]       -812.8485    896.636     -0.907      0.365   -2570.222     944.525
# C(region)[T.Республика Алтай]      -767.3827    698.099     -1.099      0.272   -2135.632     600.866
# C(region)[T.Тульская область]      -343.7778    715.097     -0.481      0.631   -1745.342    1057.786
# C(region)[T.Хабаровский край]      -485.8069    709.550     -0.685      0.494   -1876.498     904.885
# treatment_period                   1064.4085    544.343      1.955      0.051      -2.485    2131.302
# treatment_1                         290.7496    257.226      1.130      0.258    -213.405     794.904
# treatment_period:treatment_1       -920.3422    696.292     -1.322      0.186   -2285.049     444.364
# ==============================================================================
# Omnibus:                      464.048   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           287521.779
# Skew:                          12.520   Prob(JB):                         0.00
# Kurtosis:                     176.326   Cond. No.                         8.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
initial_housing_data = initial[["raion", "region", "treatment_1", "treatment_period", "housing"]].copy()
initial_housing_data.dropna(inplace=True)
initial_housing = sm_f.ols(formula="housing ~ treatment_period*treatment_1", data=initial_housing_data).fit(cov_type="cluster", cov_kwds={'groups': initial_housing_data['region']})
initial_housing.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                housing   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                     2.781
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.132
# Time:                        03:04:36   Log-Likelihood:                -2553.8
# No. Observations:                 232   AIC:                             5116.
# Df Residuals:                     228   BIC:                             5129.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     4699.7802   3145.145      1.494      0.135   -1464.591    1.09e+04
# treatment_period              -712.2682   3361.834     -0.212      0.832   -7301.343    5876.806
# treatment_1                  -3850.1907   3067.598     -1.255      0.209   -9862.572    2162.191
# treatment_period:treatment_1   940.5290   3414.838      0.275      0.783   -5752.430    7633.488
# ==============================================================================
# Omnibus:                      359.787   Durbin-Watson:                   1.638
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            49772.620
# Skew:                           7.565   Prob(JB):                         0.00
# Kurtosis:                      73.142   Cond. No.                         6.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
initial_housing_data = initial[["raion", "region", "treatment_1", "treatment_period", "housing"]].copy()
initial_housing_data.dropna(inplace=True)
initial_housing = sm_f.ols(formula="housing ~ treatment_period*treatment_1 + C(region)", data=initial_housing_data).fit(cov_type="HC3")
initial_housing.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                housing   R-squared:                       0.102
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     3.649
# Date:                Wed, 10 May 2023   Prob (F-statistic):           0.000284
# Time:                        03:04:36   Log-Likelihood:                -2542.3
# No. Observations:                 232   AIC:                             5105.
# Df Residuals:                     222   BIC:                             5139.
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          5571.9877   4261.116      1.308      0.191   -2779.645    1.39e+04
# C(region)[T.Мурманская область]   -3811.0893   4779.877     -0.797      0.425   -1.32e+04    5557.298
# C(region)[T.Новгородская область] -6314.5450   4989.342     -1.266      0.206   -1.61e+04    3464.385
# C(region)[T.Приморский край]      -4597.1956   4842.980     -0.949      0.342   -1.41e+04    4894.871
# C(region)[T.Республика Алтай]     -4482.7988   4226.968     -1.061      0.289   -1.28e+04    3801.906
# C(region)[T.Тульская область]     -3906.3366   4184.800     -0.933      0.351   -1.21e+04    4295.721
# C(region)[T.Хабаровский край]      7852.8324   5497.343      1.428      0.153   -2921.761    1.86e+04
# treatment_period                   2244.7179   2258.024      0.994      0.320   -2180.927    6670.363
# treatment_1                       -1702.3437   1004.127     -1.695      0.090   -3670.396     265.709
# treatment_period:treatment_1      -1903.1431   2946.126     -0.646      0.518   -7677.443    3871.157
# ==============================================================================
# Omnibus:                      362.983   Durbin-Watson:                   1.812
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            57049.613
# Skew:                           7.623   Prob(JB):                         0.00
# Kurtosis:                      78.294   Cond. No.                         9.16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
initial_education_data = initial[["raion", "region", "treatment_1", "treatment_period", "education"]].copy()
initial_education_data.dropna(inplace=True)
initial_education = sm_f.ols(formula="education ~ treatment_period*treatment_1", data=initial_education_data).fit(cov_type="cluster", cov_kwds={'groups': initial_education_data['region']})
initial_education.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              education   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     4.882
# Date:                Wed, 10 May 2023   Prob (F-statistic):             0.0475
# Time:                        03:04:37   Log-Likelihood:                -2523.3
# No. Observations:                 241   AIC:                             5055.
# Df Residuals:                     237   BIC:                             5069.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1.388e+04   3073.194      4.516      0.000    7854.899    1.99e+04
# treatment_period             -1869.0172   3084.787     -0.606      0.545   -7915.088    4177.054
# treatment_1                  -2680.6738   3180.288     -0.843      0.399   -8913.923    3552.576
# treatment_period:treatment_1  7139.0597   3328.669      2.145      0.032     614.989    1.37e+04
# ==============================================================================
# Omnibus:                      139.074   Durbin-Watson:                   0.876
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              910.594
# Skew:                           2.267   Prob(JB):                    1.85e-198
# Kurtosis:                      11.374   Cond. No.                         6.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
initial_education_data = initial[["raion", "region", "treatment_1", "treatment_period", "education"]].copy()
initial_education_data.dropna(inplace=True)
initial_education = sm_f.ols(formula="education ~ treatment_period*treatment_1 + C(region)", data=initial_education_data).fit(cov_type="HC3")
initial_education.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              education   R-squared:                       0.393
# Model:                            OLS   Adj. R-squared:                  0.369
# Method:                 Least Squares   F-statistic:                     34.78
# Date:                Wed, 10 May 2023   Prob (F-statistic):           2.42e-38
# Time:                        03:04:37   Log-Likelihood:                -2466.0
# No. Observations:                 241   AIC:                             4952.
# Df Residuals:                     231   BIC:                             4987.
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          7521.7801    613.399     12.262      0.000    6319.540    8724.020
# C(region)[T.Мурманская область]    1.276e+04    857.016     14.890      0.000    1.11e+04    1.44e+04
# C(region)[T.Новгородская область]  -391.1527    806.647     -0.485      0.628   -1972.152    1189.846
# C(region)[T.Приморский край]       3910.2899    891.938      4.384      0.000    2162.124    5658.456
# C(region)[T.Республика Алтай]      7401.7602   1230.809      6.014      0.000    4989.418    9814.102
# C(region)[T.Тульская область]      2589.6318    993.881      2.606      0.009     641.661    4537.603
# C(region)[T.Хабаровский край]      1.431e+04   2484.375      5.761      0.000    9442.944    1.92e+04
# treatment_period                   1773.9328    679.408      2.611      0.009     442.317    3105.548
# treatment_1                       -1300.9254   1228.462     -1.059      0.290   -3708.666    1106.815
# treatment_period:treatment_1       4054.1490   2459.126      1.649      0.099    -765.649    8873.947
# ==============================================================================
# Omnibus:                      135.234   Durbin-Watson:                   1.234
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1308.327
# Skew:                           2.011   Prob(JB):                    7.95e-285
# Kurtosis:                      13.683   Cond. No.                         8.58
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %% [markdown]
# ### Models for difference

# %%
difference_roads_data = difference[["raion", "region", "treatment_1", "treatment_period", "roads"]].copy()
difference_roads_data.dropna(inplace=True)
difference_roads = sm_f.ols(formula="roads ~ treatment_period*treatment_1", data=difference_roads_data).fit(cov_type="cluster", cov_kwds={'groups': difference_roads_data['region']})
difference_roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  roads   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.015
# Method:                 Least Squares   F-statistic:                   0.09074
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.962
# Time:                        03:04:38   Log-Likelihood:                -1689.6
# No. Observations:                 200   AIC:                             3387.
# Df Residuals:                     196   BIC:                             3400.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                      548.8185    143.001      3.838      0.000     268.541     829.096
# treatment_period                22.6960    107.056      0.212      0.832    -187.130     232.522
# treatment_1                    -74.0514    183.578     -0.403      0.687    -433.858     285.756
# treatment_period:treatment_1    45.0273    331.808      0.136      0.892    -605.304     695.359
# ==============================================================================
# Omnibus:                      150.463   Durbin-Watson:                   2.053
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1335.699
# Skew:                           2.942   Prob(JB):                    9.05e-291
# Kurtosis:                      14.210   Cond. No.                         7.22
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
difference_roads_data = difference[["raion", "region", "treatment_1", "treatment_period", "roads"]].copy()
difference_roads_data.dropna(inplace=True)
difference_roads = sm_f.ols(formula="roads ~ treatment_period*treatment_1 + C(region)", data=difference_roads_data).fit(cov_type="HC3")
difference_roads.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  roads   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     3.397
# Date:                Wed, 10 May 2023   Prob (F-statistic):           0.000684
# Time:                        03:04:38   Log-Likelihood:                -1682.1
# No. Observations:                 200   AIC:                             3384.
# Df Residuals:                     190   BIC:                             3417.
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                           968.8119    320.585      3.022      0.003     340.476    1597.148
# C(region)[T.Мурманская область]    -365.4141    524.659     -0.696      0.486   -1393.726     662.898
# C(region)[T.Новгородская область]  -833.9265    326.786     -2.552      0.011   -1474.415    -193.438
# C(region)[T.Приморский край]       -731.5319    301.452     -2.427      0.015   -1322.367    -140.697
# C(region)[T.Республика Алтай]      -602.9562    345.392     -1.746      0.081   -1279.913      74.000
# C(region)[T.Тульская область]        77.2663    505.264      0.153      0.878    -913.034    1067.566
# C(region)[T.Хабаровский край]      -280.0112    367.521     -0.762      0.446   -1000.339     440.317
# treatment_period                    271.2540    186.606      1.454      0.146     -94.486     636.994
# treatment_1                        -245.4174    267.106     -0.919      0.358    -768.935     278.100
# treatment_period:treatment_1        241.6990    462.016      0.523      0.601    -663.836    1147.234
# ==============================================================================
# Omnibus:                      148.790   Durbin-Watson:                   2.135
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1347.066
# Skew:                           2.884   Prob(JB):                    3.08e-293
# Kurtosis:                      14.331   Cond. No.                         9.51
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
difference_housing_data = difference[["raion", "region", "treatment_1", "treatment_period", "housing"]].copy()
difference_housing_data.dropna(inplace=True)
difference_housing = sm_f.ols(formula="housing ~ treatment_period*treatment_1", data=difference_housing_data).fit(cov_type="cluster", cov_kwds={'groups': difference_housing_data['region']})
difference_housing.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                housing   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                     2.859
# Date:                Wed, 10 May 2023   Prob (F-statistic):              0.127
# Time:                        03:04:38   Log-Likelihood:                -2069.6
# No. Observations:                 205   AIC:                             4147.
# Df Residuals:                     201   BIC:                             4161.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1255.9096    837.816      1.499      0.134    -386.179    2897.998
# treatment_period             -1414.8755   1042.129     -1.358      0.175   -3457.411     627.660
# treatment_1                   -129.4728    846.068     -0.153      0.878   -1787.736    1528.790
# treatment_period:treatment_1   536.3016   1087.845      0.493      0.622   -1595.835    2668.438
# ==============================================================================
# Omnibus:                      159.002   Durbin-Watson:                   2.169
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13700.617
# Skew:                          -2.114   Prob(JB):                         0.00
# Kurtosis:                      42.826   Cond. No.                         7.22
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
difference_housing_data = difference[["raion", "region", "treatment_1", "treatment_period", "housing"]].copy()
difference_housing_data.dropna(inplace=True)
difference_housing = sm_f.ols(formula="housing ~ treatment_period*treatment_1 + C(region)", data=difference_housing_data).fit(cov_type="HC3")
difference_housing.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                housing   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     2.579
# Date:                Wed, 10 May 2023   Prob (F-statistic):            0.00792
# Time:                        03:04:39   Log-Likelihood:                -2065.2
# No. Observations:                 205   AIC:                             4150.
# Df Residuals:                     195   BIC:                             4184.
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          -542.9049   3250.385     -0.167      0.867   -6913.542    5827.732
# C(region)[T.Мурманская область]    1076.5577   3007.567      0.358      0.720   -4818.166    6971.282
# C(region)[T.Новгородская область]   790.4943   3000.860      0.263      0.792   -5091.083    6672.072
# C(region)[T.Приморский край]        260.2713   3050.607      0.085      0.932   -5718.809    6239.352
# C(region)[T.Республика Алтай]      2614.1250   3202.596      0.816      0.414   -3662.849    8891.099
# C(region)[T.Тульская область]      1620.4992   3069.278      0.528      0.598   -4395.176    7636.174
# C(region)[T.Хабаровский край]      3878.0799   3538.254      1.096      0.273   -3056.771    1.08e+04
# treatment_period                   -138.8748    995.561     -0.139      0.889   -2090.138    1812.388
# treatment_1                         214.1754    592.991      0.361      0.718    -948.066    1376.417
# treatment_period:treatment_1        262.8375   1265.967      0.208      0.836   -2218.413    2744.088
# ==============================================================================
# Omnibus:                      165.952   Durbin-Watson:                   2.273
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12350.485
# Skew:                          -2.334   Prob(JB):                         0.00
# Kurtosis:                      40.737   Cond. No.                         11.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """

# %%
difference_education_data = difference[["raion", "region", "treatment_1", "treatment_period", "education"]].copy()
difference_education_data.dropna(inplace=True)
difference_education = sm_f.ols(formula="education ~ treatment_period*treatment_1", data=difference_education_data).fit(cov_type="cluster", cov_kwds={'groups': difference_education_data['region']})
difference_education.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              education   R-squared:                       0.043
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     21.24
# Date:                Wed, 10 May 2023   Prob (F-statistic):            0.00135
# Time:                        03:04:39   Log-Likelihood:                -2086.2
# No. Observations:                 212   AIC:                             4180.
# Df Residuals:                     208   BIC:                             4194.
# Df Model:                           3
# Covariance Type:              cluster
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     3390.3993   1162.727      2.916      0.004    1111.495    5669.303
# treatment_period             -1153.2047    771.307     -1.495      0.135   -2664.940     358.530
# treatment_1                  -1610.7167    534.515     -3.013      0.003   -2658.346    -563.087
# treatment_period:treatment_1 -1760.7220    758.507     -2.321      0.020   -3247.368    -274.076
# ==============================================================================
# Omnibus:                       63.871   Durbin-Watson:                   1.258
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              143.665
# Skew:                           1.398   Prob(JB):                     6.36e-32
# Kurtosis:                       5.906   Cond. No.                         7.30
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
difference_education_data = difference[["raion", "region", "treatment_1", "treatment_period", "education"]].copy()
difference_education_data.dropna(inplace=True)
difference_education = sm_f.ols(formula="education ~ treatment_period*treatment_1 + C(region)", data=difference_education_data).fit(cov_type="HC3")
difference_education.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              education   R-squared:                       0.311
# Model:                            OLS   Adj. R-squared:                  0.280
# Method:                 Least Squares   F-statistic:                     12.55
# Date:                Wed, 10 May 2023   Prob (F-statistic):           9.37e-16
# Time:                        03:04:40   Log-Likelihood:                -2051.4
# No. Observations:                 212   AIC:                             4123.
# Df Residuals:                     202   BIC:                             4156.
# Df Model:                           9
# Covariance Type:                  HC3
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          8615.5071    992.548      8.680      0.000    6670.149    1.06e+04
# C(region)[T.Мурманская область]   -7487.5007   1007.933     -7.429      0.000   -9463.013   -5511.988
# C(region)[T.Новгородская область] -6648.2498   1090.290     -6.098      0.000   -8785.180   -4511.320
# C(region)[T.Приморский край]      -8199.6363   1000.369     -8.197      0.000   -1.02e+04   -6238.949
# C(region)[T.Республика Алтай]     -3129.2807   1200.056     -2.608      0.009   -5481.346    -777.215
# C(region)[T.Тульская область]     -6830.5649   1125.038     -6.071      0.000   -9035.599   -4625.531
# C(region)[T.Хабаровский край]     -4604.2110   1386.157     -3.322      0.001   -7321.030   -1887.392
# treatment_period                    365.8902    618.872      0.591      0.554    -847.077    1578.858
# treatment_1                        -791.9551    666.685     -1.188      0.235   -2098.634     514.724
# treatment_period:treatment_1      -1447.4104   2067.236     -0.700      0.484   -5499.119    2604.298
# ==============================================================================
# Omnibus:                       86.064   Durbin-Watson:                   1.551
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              435.434
# Skew:                           1.505   Prob(JB):                     2.80e-95
# Kurtosis:                       9.343   Cond. No.                         9.75
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# """
